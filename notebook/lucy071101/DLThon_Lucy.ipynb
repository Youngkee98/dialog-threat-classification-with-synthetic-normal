# %% [markdown]
# # 1. KoELECTRA + LSTM
# - 이진 분류를 제대로 못함 (일반 대화를 제대로 분류하지 못함)
# - 그에 반해 다중 분류 작업은 준수한 것 같음
# - 따라서 이진 분류 부분을 수정하기로 함

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
from torch.optim import AdamW
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import WeightedRandomSampler

# KoELECTRA tokenizer 로드
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-discriminator")

# 클래스명-정수 매핑
label_map_str2int = {
    '협박 대화': 0,
    '갈취 대화': 1,
    '직장 내 괴롭힘 대화': 2,
    '기타 괴롭힘 대화': 3,
    '일반대화': 4
}
label_map_int2str = {v: k for k, v in label_map_str2int.items()}

# Dataset 클래스 정의
class TextDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len, task='binary'):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.task = task
        self.label_map = label_map_str2int

        # 디버깅을 위한 레이블 분포 출력
        if self.task == 'binary':
            self.binary_labels = [0 if self.label_map[row['class']] == 4 else 1 for _, row in self.data.iterrows()]
            unique, counts = np.unique(self.binary_labels, return_counts=True)
            print(f"Binary label distribution: {dict(zip(unique, counts))}")
        elif self.task == 'multi':
            self.multi_labels = [self.label_map[row['class']] for _, row in self.data.iterrows()]
            unique, counts = np.unique(self.multi_labels, return_counts=True)
            print(f"Multi-class label distribution: {dict(zip(unique, counts))}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = self.data.iloc[index]['conversation']
        label_str = self.data.iloc[index]['class']
        orig_label = self.label_map[label_str]  # 원래 레이블 (0-4)

        inputs = self.tokenizer(text,
                                truncation=True,
                                padding='max_length',
                                max_length=self.max_len,
                                return_tensors="pt")

        input_ids = inputs['input_ids'].squeeze()
        attention_mask = inputs['attention_mask'].squeeze()

        # 일반대화(4) → 0, 나머지(0-3) → 1로 이진 분류
        if self.task == 'binary':
            binary_label = 0 if orig_label == 4 else 1
            return {
                'input_ids': input_ids,
                'attention_mask': attention_mask,
                'label': torch.tensor(binary_label, dtype=torch.long)
            }
        # 다중 분류용 - 일반대화는 제외하고 레이블을 그대로 사용 (0-3)
        elif self.task == 'multi':
            return {
                'input_ids': input_ids,
                'attention_mask': attention_mask,
                'label': torch.tensor(orig_label, dtype=torch.long)
            }

    # 샘플링 가중치 계산용 함수 추가
    def get_labels(self):
        if self.task == 'binary':
            return self.binary_labels
        elif self.task == 'multi':
            return self.multi_labels

# KoELECTRA + LSTM 이진 분류 모델
class KoELECTRA_LSTM_BinaryClassifier(nn.Module):
    def __init__(self, bert_model_name='monologg/koelectra-base-discriminator', hidden_size=128, lstm_layers=1, dropout=0.3, freeze_bert=False):
        super().__init__()
        self.bert = AutoModel.from_pretrained(bert_model_name)
        self.freeze_bert = freeze_bert
        self.lstm = nn.LSTM(input_size=self.bert.config.hidden_size, hidden_size=hidden_size,
                            num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden_size * 2, 2)  # 이진 분류: 0(일반), 1(폭력)

    def forward(self, input_ids, attention_mask):
        if self.freeze_bert:
            with torch.no_grad():
                bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        else:
            bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        sequence_output = bert_output.last_hidden_state
        lstm_output, _ = self.lstm(sequence_output)
        pooled_output = lstm_output[:, -1, :]
        out = self.dropout(pooled_output)
        logits = self.classifier(out)
        return logits

# KoELECTRA + LSTM 다중 분류 모델 (4개 클래스)
class KoELECTRA_LSTM_MultiClassifier(nn.Module):
    def __init__(self, bert_model_name='monologg/koelectra-base-discriminator', hidden_size=128, lstm_layers=1, dropout=0.3, freeze_bert=False):
        super().__init__()
        self.bert = AutoModel.from_pretrained(bert_model_name)
        self.freeze_bert = freeze_bert
        self.lstm = nn.LSTM(input_size=self.bert.config.hidden_size, hidden_size=hidden_size,
                            num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden_size * 2, 4)  # 4개 클래스 (0-3)

    def forward(self, input_ids, attention_mask):
        if self.freeze_bert:
            with torch.no_grad():
                bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        else:
            bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        sequence_output = bert_output.last_hidden_state
        lstm_output, _ = self.lstm(sequence_output)
        pooled_output = lstm_output[:, -1, :]
        out = self.dropout(pooled_output)
        logits = self.classifier(out)
        return logits

# 학습 및 검증 함수
def train(model, train_loader, val_loader, optimizer, criterion, device, epochs=5, patience=2):
    best_val_loss = float('inf')
    best_val_f1 = 0.0
    patience_counter = 0

    for epoch in range(epochs):
        # 학습
        model.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        # 검증
        model.eval()
        val_loss = 0
        val_preds = []
        val_true = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_true.extend(labels.cpu().numpy())

        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = accuracy_score(val_true, val_preds)
        val_f1 = f1_score(val_true, val_preds, average='weighted')

        # 클래스별 성능 확인
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}")

        # 검증 데이터의 클래스별 성능 출력
        val_report = classification_report(val_true, val_preds, output_dict=True)
        for cls in sorted(set(val_true)):
            print(f"Class {cls}: F1={val_report[str(cls)]['f1-score']:.4f}, Recall={val_report[str(cls)]['recall']:.4f}")

        # 조기 종료 체크 (F1 스코어 기반으로 변경)
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            patience_counter = 0
            # 최적 모델 저장
            torch.save(model.state_dict(), 'best_model.pt')
            print("새로운 최적 모델 저장!")
        else:
            patience_counter += 1
            print(f"성능 개선 없음: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("조기 종료!")
                break

    # 최적 모델 로드
    model.load_state_dict(torch.load('best_model.pt'))
    return model

# 학습 준비
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 데이터 로드
data = pd.read_csv("/content/sample_data/merged_dataset.csv")
print(f"Total data size: {len(data)}")

# 클래스 분포 확인
class_counts = data['class'].value_counts()
print("Class distribution:")
print(class_counts)

# 일반대화 포함 → 이진 분류용, 일반대화 제외 → 다중 분류용
data_binary = data.copy()
data_multi = data[data['class'] != '일반대화'].copy()

# 데이터 분할
train_binary, val_binary = train_test_split(data_binary, test_size=0.2, stratify=data_binary['class'], random_state=42)
train_multi, val_multi = train_test_split(data_multi, test_size=0.2, stratify=data_multi['class'], random_state=42)

print(f"Binary training set: {len(train_binary)}, validation set: {len(val_binary)}")
print(f"Multi training set: {len(train_multi)}, validation set: {len(val_multi)}")

# 데이터셋 생성
train_dataset_binary = TextDataset(train_binary, tokenizer, max_len=128, task='binary')
val_dataset_binary = TextDataset(val_binary, tokenizer, max_len=128, task='binary')

train_dataset_multi = TextDataset(train_multi, tokenizer, max_len=128, task='multi')
val_dataset_multi = TextDataset(val_multi, tokenizer, max_len=128, task='multi')

# 불균형 데이터 처리를 위한 가중치 샘플링 설정 (이진 분류용)
binary_labels = train_dataset_binary.get_labels()
unique_binary_labels = np.unique(binary_labels)
binary_class_weights = compute_class_weight(class_weight='balanced',
                                           classes=unique_binary_labels,
                                           y=binary_labels)
# 클래스 인덱스를 dictionary로 변환
binary_weight_dict = {cls: weight for cls, weight in zip(unique_binary_labels, binary_class_weights)}
binary_samples_weight = [binary_weight_dict[lbl] for lbl in binary_labels]
binary_sampler = WeightedRandomSampler(weights=binary_samples_weight,
                                      num_samples=len(binary_samples_weight),
                                      replacement=True)

# 불균형 데이터 처리를 위한 가중치 샘플링 설정 (다중 분류용)
multi_labels = train_dataset_multi.get_labels()
unique_multi_labels = np.unique(multi_labels)
multi_class_weights = compute_class_weight(class_weight='balanced',
                                         classes=unique_multi_labels,
                                         y=multi_labels)
# 클래스 인덱스를 dictionary로 변환
multi_weight_dict = {cls: weight for cls, weight in zip(unique_multi_labels, multi_class_weights)}
multi_samples_weight = [multi_weight_dict[lbl] for lbl in multi_labels]
multi_sampler = WeightedRandomSampler(weights=multi_samples_weight,
                                    num_samples=len(multi_samples_weight),
                                    replacement=True)

# 데이터로더 생성 (가중치 샘플러 적용)
train_loader_binary = DataLoader(train_dataset_binary, batch_size=16, sampler=binary_sampler)
val_loader_binary = DataLoader(val_dataset_binary, batch_size=16, shuffle=False)

train_loader_multi = DataLoader(train_dataset_multi, batch_size=16, sampler=multi_sampler)
val_loader_multi = DataLoader(val_dataset_multi, batch_size=16, shuffle=False)

# 모델 생성 - BERT 미세조정 활성화
model_binary = KoELECTRA_LSTM_BinaryClassifier(freeze_bert=False).to(device)
model_multi = KoELECTRA_LSTM_MultiClassifier(freeze_bert=False).to(device)

# 손실 함수 정의 (클래스 가중치 적용)
binary_loss_weights = torch.tensor(binary_class_weights, dtype=torch.float).to(device)
criterion_binary = nn.CrossEntropyLoss(weight=binary_loss_weights)

multi_loss_weights = torch.tensor(multi_class_weights, dtype=torch.float).to(device)
criterion_multi = nn.CrossEntropyLoss(weight=multi_loss_weights)

# 옵티마이저 설정 (더 낮은 학습률 사용)
optimizer_binary = AdamW(model_binary.parameters(), lr=2e-5)
optimizer_multi = AdamW(model_multi.parameters(), lr=2e-5)

# 학습률 스케줄러 추가
from transformers import get_linear_schedule_with_warmup

# 총 훈련 스텝 계산
num_epochs = 5
total_steps_binary = len(train_loader_binary) * num_epochs
warmup_steps_binary = int(total_steps_binary * 0.1)  # 10% 웜업
scheduler_binary = get_linear_schedule_with_warmup(
    optimizer_binary, num_warmup_steps=warmup_steps_binary, num_training_steps=total_steps_binary
)

total_steps_multi = len(train_loader_multi) * num_epochs
warmup_steps_multi = int(total_steps_multi * 0.1)  # 10% 웜업
scheduler_multi = get_linear_schedule_with_warmup(
    optimizer_multi, num_warmup_steps=warmup_steps_multi, num_training_steps=total_steps_multi
)

# 모델 평가 지표 설정 - 전역 변수로 선언하지 않고 함수 내에서 사용
# 각 모델 학습 함수 내에서 best_val_f1을 정의하도록 수정

# 모델 학습 함수 수정 (스케줄러 적용)
def train_with_scheduler(model, train_loader, val_loader, optimizer, scheduler, criterion, device, epochs=5, patience=2):
    best_val_f1 = 0.0
    patience_counter = 0

    for epoch in range(epochs):
        # 학습
        model.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()

            # 그래디언트 클리핑 추가
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()
            scheduler.step()  # 스케줄러 업데이트

            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        # 검증
        model.eval()
        val_loss = 0
        val_preds = []
        val_true = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_true.extend(labels.cpu().numpy())

        # 클래스별 성능 평가
        val_report = classification_report(val_true, val_preds, output_dict=True)
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = accuracy_score(val_true, val_preds)
        val_f1 = f1_score(val_true, val_preds, average='weighted')

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}")

        # 각 클래스별 성능 출력
        for cls in sorted(set(val_true)):
            cls_str = str(cls)
            if cls_str in val_report:
                print(f"Class {cls}: F1={val_report[cls_str]['f1-score']:.4f}, Recall={val_report[cls_str]['recall']:.4f}")

        # 조기 종료 체크 (F1 스코어 기반)
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            patience_counter = 0
            # 최적 모델 저장
            torch.save(model.state_dict(), 'best_model.pt')
            print("새로운 최적 모델 저장!")
        else:
            patience_counter += 1
            print(f"성능 개선 없음: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("조기 종료!")
                break

    # 최적 모델 로드
    model.load_state_dict(torch.load('best_model.pt'))
    return model

# 모델 학습 실행
print("\n[INFO] Training Binary Classifier...")
model_binary = train_with_scheduler(model_binary, train_loader_binary, val_loader_binary,
                   optimizer_binary, scheduler_binary, criterion_binary, device, epochs=num_epochs, patience=2)

print("\n[INFO] Training Multi Classifier...")
model_multi = train_with_scheduler(model_multi, train_loader_multi, val_loader_multi,
                  optimizer_multi, scheduler_multi, criterion_multi, device, epochs=num_epochs, patience=2)

# 추론 함수 개선 - 확률 기반 임계값 추가
def predict(text, binary_threshold=0.6):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    with torch.no_grad():
        # 이진 분류 (일반/폭력)
        binary_logits = model_binary(input_ids=input_ids, attention_mask=attention_mask)
        binary_probs = torch.softmax(binary_logits, dim=1)

        # 확률값 추출
        normal_prob = binary_probs[0][0].item()  # 일반대화 확률
        violent_prob = binary_probs[0][1].item()  # 폭력대화 확률

        print(f"일반대화 확률: {normal_prob:.4f}, 폭력대화 확률: {violent_prob:.4f}")

        # 확률 기반 분류 (임계값 적용)
        binary_pred = 1 if violent_prob > binary_threshold else 0

        print(f"Binary prediction: {binary_pred} ({'폭력대화' if binary_pred == 1 else '일반대화'})")

        # 이진 분류에서 0이면 일반 대화 (원래 레이블 4)
        if binary_pred == 0:
            return 4  # 일반대화

        # 폭력 대화인 경우, 세부 유형 분류
        multi_logits = model_multi(input_ids=input_ids, attention_mask=attention_mask)
        multi_probs = torch.softmax(multi_logits, dim=1)
        multi_pred = torch.argmax(multi_logits, dim=1).item()

        # 확률값 출력
        for i, prob in enumerate(multi_probs[0].cpu().numpy()):
            print(f"Class {i} ({label_map_int2str[i]}) 확률: {prob:.4f}")

        # multi_pred는 0-3 사이의 값으로, 원래 레이블 체계와 일치함
        print(f"Multi prediction: {multi_pred} ({label_map_int2str[multi_pred]})")
        return multi_pred

# 테스트셋 평가
print("\n[INFO] Loading test set...")
test_df = pd.read_csv("/content/sample_data/test.csv")
print(f"Test set size: {len(test_df)}")

predicted_labels = []

# 원래 레이블 매핑과 동일한 매핑 사용
label_map = label_map_int2str

# text 컬럼을 기준으로 예측 수행
test_texts = test_df["text"].tolist()
for i, text in enumerate(test_texts):
    print(f"\nPredicting sample {i+1}/{len(test_texts)}")
    pred = predict(text, binary_threshold=0.6)  # 임계값 적용
    predicted_labels.append(pred)
    print(f"Final prediction: {pred} ({label_map[pred]})")

test_df["prediction"] = predicted_labels
test_df["prediction_label"] = test_df["prediction"].map(label_map)

# 클래스별 예측 분포 확인
pred_counts = test_df["prediction_label"].value_counts()
print("\nPrediction distribution:")
print(pred_counts)

# 실제 레이블이 있는 경우 평가 지표 계산
if "class" in test_df.columns:
    test_df["true_label_id"] = test_df["class"].map(label_map_str2int)
    true_labels = test_df["true_label_id"].tolist()

    print("\n[INFO] Classification Report:")
    print(classification_report(true_labels, predicted_labels, target_names=list(label_map_str2int.keys())))

    accuracy = accuracy_score(true_labels, predicted_labels)
    f1 = f1_score(true_labels, predicted_labels, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1 Score (weighted): {f1:.4f}")

# 저장
test_df.to_csv("/content/test_predictions_improved.csv", index=False)
print("\n[INFO] 예측 결과 저장 완료: /content/test_predictions_improved.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5b33025e10ee> in <cell line: 0>()
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 from torch.utils.data import Dataset, DataLoader
#       4 from transformers import AutoModel, AutoTokenizer
#       5 from torch.optim import AdamW
#
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py in <module>
#    2591
#    2592
# -> 2593 from torch import (
#    2594     export as export,
#    2595     func as func,
#
# /usr/local/lib/python3.11/dist-packages/torch/func/__init__.py in <module>
# ----> 1 from torch._functorch.eager_transforms import (
#       2     vjp,
#       3     jvp,
#       4     jacrev,
#       5     jacfwd,
#
# /usr/local/lib/python3.11/dist-packages/torch/_functorch/eager_transforms.py in <module>
#      31 from torch._functorch.utils import argnums_t, exposed_in
#      32 from torch._subclasses.functional_tensor import FunctionalTensor
# ---> 33 from torch.fx.experimental import const_fold
#      34 from torch.fx.experimental.proxy_tensor import make_fx
#      35 from torch.utils import _pytree as pytree
#
# /usr/local/lib/python3.11/dist-packages/torch/fx/experimental/const_fold.py in <module>
#      15
#      16
# ---> 17 class FoldedGraphModule(torch.fx.GraphModule):
#      18     """
#      19     FoldedGraphModule is a GraphModule which also contains another
#
# AttributeError: partially initialized module 'torch' has no attribute 'fx' (most likely due to a circular import)

# %% [markdown]
# # 2. 이진 분류 : KcBERT-base / 다중 분류 : KoELECTRA + LSTM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer, BertModel, BertTokenizer
from torch.optim import AdamW
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import WeightedRandomSampler

# KoELECTRA tokenizer 로드 - 다중 분류기용
electra_tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-discriminator")
# KcBERT tokenizer 로드 - 이진 분류기용
bert_tokenizer = BertTokenizer.from_pretrained("beomi/kcbert-base")

# 클래스명-정수 매핑
label_map_str2int = {
    '협박 대화': 0,
    '갈취 대화': 1,
    '직장 내 괴롭힘 대화': 2,
    '기타 괴롭힘 대화': 3,
    '일반대화': 4
}
label_map_int2str = {v: k for k, v in label_map_str2int.items()}

# 이진 분류용 SharedBERT 모델
class SharedBERT(nn.Module):
    def __init__(self, model_name="beomi/kcbert-base"):
        super().__init__()
        self.bert = BertModel.from_pretrained(model_name)
        for p in self.bert.parameters():
            p.requires_grad = False

    def forward(self, input_ids, attention_mask):
        return self.bert(input_ids=input_ids, attention_mask=attention_mask).pooler_output

# 이진 분류기 정의
class BinaryClassifier(nn.Module):
    def __init__(self, hidden_size=768):
        super().__init__()
        self.classifier = nn.Linear(hidden_size, 2)

    def forward(self, cls_output):
        return self.classifier(cls_output)

# 이진 분류 데이터셋
class BinaryClassificationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.texts = dataframe['conversation'].tolist()
        self.labels = [label_map_str2int[label] for label in dataframe['class'].tolist()]
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.binary_labels = [0 if label == 4 else 1 for label in self.labels]

        # 디버깅을 위한 레이블 분포 출력
        unique, counts = np.unique(self.binary_labels, return_counts=True)
        print(f"Binary label distribution: {dict(zip(unique, counts))}")

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )
        item = {key: val.squeeze(0) for key, val in encoding.items()}
        item['label'] = torch.tensor(self.binary_labels[idx], dtype=torch.long)
        item['original_label'] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

# 다중 분류용 데이터셋 클래스 정의
class MultiClassificationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.label_map = label_map_str2int

        # 폭력 대화만 사용 (일반대화 제외)
        self.data = self.data[self.data['class'] != '일반대화'].copy()

        # 다중 레이블 설정
        self.multi_labels = [self.label_map[row['class']] for _, row in self.data.iterrows()]
        unique, counts = np.unique(self.multi_labels, return_counts=True)
        print(f"Multi-class label distribution: {dict(zip(unique, counts))}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = self.data.iloc[index]['conversation']
        label_str = self.data.iloc[index]['class']
        label = self.label_map[label_str]  # 0-3 레이블

        inputs = self.tokenizer(text,
                               truncation=True,
                               padding='max_length',
                               max_length=self.max_len,
                               return_tensors="pt")

        input_ids = inputs['input_ids'].squeeze()
        attention_mask = inputs['attention_mask'].squeeze()

        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'label': torch.tensor(label, dtype=torch.long)
        }

    # 샘플링 가중치 계산용 함수
    def get_labels(self):
        return self.multi_labels

# KoELECTRA + LSTM 다중 분류 모델 (4개 클래스)
class KoELECTRA_LSTM_MultiClassifier(nn.Module):
    def __init__(self, bert_model_name='monologg/koelectra-base-discriminator', hidden_size=128, lstm_layers=1, dropout=0.3, freeze_bert=False):
        super().__init__()
        self.bert = AutoModel.from_pretrained(bert_model_name)
        self.freeze_bert = freeze_bert
        self.lstm = nn.LSTM(input_size=self.bert.config.hidden_size, hidden_size=hidden_size,
                            num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden_size * 2, 4)  # 4개 클래스 (0-3)

    def forward(self, input_ids, attention_mask):
        if self.freeze_bert:
            with torch.no_grad():
                bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        else:
            bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        sequence_output = bert_output.last_hidden_state
        lstm_output, _ = self.lstm(sequence_output)
        pooled_output = lstm_output[:, -1, :]
        out = self.dropout(pooled_output)
        logits = self.classifier(out)
        return logits

# 이진 분류기 학습 함수
def train_binary_model(shared_bert, binary_head, train_loader, optimizer, device, epochs=10):
    for epoch in range(epochs):
        shared_bert.eval()  # 사전 학습된 BERT는 고정
        binary_head.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            with torch.no_grad():
                cls_output = shared_bert(input_ids, attention_mask)
            logits = binary_head(cls_output)
            loss = F.cross_entropy(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(logits, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        print(f"[Binary Epoch {epoch+1}/{epochs}] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}")

    return binary_head

# 다중 분류기 학습 함수
def train_with_scheduler(model, train_loader, val_loader, optimizer, scheduler, criterion, device, epochs=5, patience=2):
    best_val_f1 = 0.0
    patience_counter = 0

    for epoch in range(epochs):
        # 학습
        model.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()

            # 그래디언트 클리핑 추가
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()
            scheduler.step()  # 스케줄러 업데이트

            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        # 검증
        model.eval()
        val_loss = 0
        val_preds = []
        val_true = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_true.extend(labels.cpu().numpy())

        # 클래스별 성능 평가
        val_report = classification_report(val_true, val_preds, output_dict=True)
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = accuracy_score(val_true, val_preds)
        val_f1 = f1_score(val_true, val_preds, average='weighted')

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}")

        # 각 클래스별 성능 출력
        for cls in sorted(set(val_true)):
            cls_str = str(cls)
            if cls_str in val_report:
                print(f"Class {cls}: F1={val_report[cls_str]['f1-score']:.4f}, Recall={val_report[cls_str]['recall']:.4f}")

        # 조기 종료 체크 (F1 스코어 기반)
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            patience_counter = 0
            # 최적 모델 저장
            torch.save(model.state_dict(), 'best_multi_model.pt')
            print("새로운 최적 모델 저장!")
        else:
            patience_counter += 1
            print(f"성능 개선 없음: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("조기 종료!")
                break

    # 최적 모델 로드
    model.load_state_dict(torch.load('best_multi_model.pt'))
    return model

# 학습 준비
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 데이터 로드
data = pd.read_csv("/content/sample_data/train_toxic.csv")
print(f"Total data size: {len(data)}")

# 클래스 분포 확인
class_counts = data['class'].value_counts()
print("Class distribution:")
print(class_counts)

# 이진 분류 및 다중 분류를 위한 데이터 분할
train_data, val_data = train_test_split(data, test_size=0.2, stratify=data['class'], random_state=42)
print(f"Training set: {len(train_data)}, validation set: {len(val_data)}")

# 이진 분류 모델 준비
shared_bert = SharedBERT(model_name="beomi/kcbert-base").to(device)
binary_head = BinaryClassifier().to(device)

# 이진 분류 데이터셋 및 데이터로더 생성
train_dataset_binary = BinaryClassificationDataset(train_data, bert_tokenizer, max_length=128)
val_dataset_binary = BinaryClassificationDataset(val_data, bert_tokenizer, max_length=128)

# 이진 분류 데이터로더
train_loader_binary = DataLoader(train_dataset_binary, batch_size=32, shuffle=True)
val_loader_binary = DataLoader(val_dataset_binary, batch_size=32, shuffle=False)

# 이진 분류 모델 학습
optimizer_binary = torch.optim.Adam(binary_head.parameters(), lr=2e-5)

print("\n[INFO] Training Binary Classifier...")
binary_head = train_binary_model(shared_bert, binary_head, train_loader_binary, optimizer_binary, device, epochs=10)

# 이진 분류 모델 저장
torch.save(binary_head.state_dict(), "binary_classifier.pt")
print("Binary classifier model saved as 'binary_classifier.pt'")

# 다중 분류용 데이터셋 준비 - 일반대화 제외
train_dataset_multi = MultiClassificationDataset(train_data, electra_tokenizer, max_len=128)
val_dataset_multi = MultiClassificationDataset(val_data, electra_tokenizer, max_len=128)

# 불균형 데이터 처리를 위한 가중치 샘플링 설정 (다중 분류용)
multi_labels = train_dataset_multi.get_labels()
unique_multi_labels = np.unique(multi_labels)
multi_class_weights = compute_class_weight(class_weight='balanced',
                                         classes=unique_multi_labels,
                                         y=multi_labels)
# 클래스 인덱스를 dictionary로 변환
multi_weight_dict = {cls: weight for cls, weight in zip(unique_multi_labels, multi_class_weights)}
multi_samples_weight = [multi_weight_dict[lbl] for lbl in multi_labels]
multi_sampler = WeightedRandomSampler(weights=multi_samples_weight,
                                    num_samples=len(multi_samples_weight),
                                    replacement=True)

# 다중 분류용 데이터로더 생성
train_loader_multi = DataLoader(train_dataset_multi, batch_size=16, sampler=multi_sampler)
val_loader_multi = DataLoader(val_dataset_multi, batch_size=16, shuffle=False)

# 다중 분류 모델 생성
model_multi = KoELECTRA_LSTM_MultiClassifier(freeze_bert=False).to(device)

# 손실 함수 정의 (클래스 가중치 적용) - 다중 분류용
multi_loss_weights = torch.tensor(multi_class_weights, dtype=torch.float).to(device)
criterion_multi = nn.CrossEntropyLoss(weight=multi_loss_weights)

# 옵티마이저 설정 - 다중 분류용
optimizer_multi = AdamW(model_multi.parameters(), lr=2e-5)

# 학습률 스케줄러 추가
from transformers import get_linear_schedule_with_warmup

# 총 훈련 스텝 계산 - 다중 분류용
num_epochs = 5
total_steps_multi = len(train_loader_multi) * num_epochs
warmup_steps_multi = int(total_steps_multi * 0.1)  # 10% 웜업
scheduler_multi = get_linear_schedule_with_warmup(
    optimizer_multi, num_warmup_steps=warmup_steps_multi, num_training_steps=total_steps_multi
)

# 다중 분류 모델 학습
print("\n[INFO] Training Multi Classifier...")
model_multi = train_with_scheduler(model_multi, train_loader_multi, val_loader_multi,
                  optimizer_multi, scheduler_multi, criterion_multi, device, epochs=num_epochs, patience=2)

# 추론 함수
def predict(text, binary_threshold=0.5):
    # 이진 분류 (일반/폭력)
    inputs_bert = bert_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    input_ids_bert = inputs_bert["input_ids"].to(device)
    attention_mask_bert = inputs_bert["attention_mask"].to(device)

    with torch.no_grad():
        # SharedBERT로 특성 추출
        cls_output = shared_bert(input_ids_bert, attention_mask_bert)
        # 이진 분류
        binary_logits = binary_head(cls_output)
        binary_probs = F.softmax(binary_logits, dim=1)

        # 확률값 추출
        normal_prob = binary_probs[0][0].item()  # 일반대화 확률
        violent_prob = binary_probs[0][1].item()  # 폭력대화 확률

        print(f"일반대화 확률: {normal_prob:.4f}, 폭력대화 확률: {violent_prob:.4f}")

        # 임계값 기반 분류
        binary_pred = 1 if violent_prob > binary_threshold else 0

        print(f"Binary prediction: {binary_pred} ({'폭력대화' if binary_pred == 1 else '일반대화'})")

        # 일반 대화로 분류된 경우
        if binary_pred == 0:
            return 4  # 일반대화

        # 폭력 대화로 분류된 경우, 세부 유형 분류
        inputs_electra = electra_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
        input_ids_electra = inputs_electra["input_ids"].to(device)
        attention_mask_electra = inputs_electra["attention_mask"].to(device)

        multi_logits = model_multi(input_ids=input_ids_electra, attention_mask=attention_mask_electra)
        multi_probs = F.softmax(multi_logits, dim=1)
        multi_pred = torch.argmax(multi_logits, dim=1).item()

        # 확률값 출력
        for i, prob in enumerate(multi_probs[0].cpu().numpy()):
            print(f"Class {i} ({label_map_int2str[i]}) 확률: {prob:.4f}")

        print(f"Multi prediction: {multi_pred} ({label_map_int2str[multi_pred]})")
        return multi_pred

# 테스트셋 평가
print("\n[INFO] Loading test set...")
test_df = pd.read_csv("/content/sample_data/test.csv")
print(f"Test set size: {len(test_df)}")

predicted_labels = []

# 원래 레이블 매핑과 동일한 매핑 사용
label_map = label_map_int2str

# text 컬럼을 기준으로 예측 수행
test_texts = test_df["text"].tolist()
for i, text in enumerate(test_texts):
    print(f"\nPredicting sample {i+1}/{len(test_texts)}")
    pred = predict(text, binary_threshold=0.6)  # 임계값 적용
    predicted_labels.append(pred)
    print(f"Final prediction: {pred} ({label_map[pred]})")

test_df["prediction"] = predicted_labels
test_df["prediction_label"] = test_df["prediction"].map(label_map)

# 클래스별 예측 분포 확인
pred_counts = test_df["prediction_label"].value_counts()
print("\nPrediction distribution:")
print(pred_counts)

# 실제 레이블이 있는 경우 평가 지표 계산
if "class" in test_df.columns:
    test_df["true_label_id"] = test_df["class"].map(label_map_str2int)
    true_labels = test_df["true_label_id"].tolist()

    print("\n[INFO] Classification Report:")
    print(classification_report(true_labels, predicted_labels, target_names=list(label_map_str2int.keys())))

    accuracy = accuracy_score(true_labels, predicted_labels)
    f1 = f1_score(true_labels, predicted_labels, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1 Score (weighted): {f1:.4f}")

# 결과 저장
test_df.to_csv("/content/test_predictions_combined.csv", index=False)
print("\n[INFO] 예측 결과 저장 완료: /content/test_predictions_combined.csv")
# Out:
# Using device: cuda
# Total data size: 7784
# Class distribution:
# class
# 일반대화           3834
# 기타 괴롭힘 대화      1094
# 갈취 대화           981
# 직장 내 괴롭힘 대화     979
# 협박 대화           896
# Name: count, dtype: int64
# Training set: 6227, validation set: 1557
# Binary label distribution: {np.int64(0): np.int64(3067), np.int64(1): np.int64(3160)}
# Binary label distribution: {np.int64(0): np.int64(767), np.int64(1): np.int64(790)}
#
# [INFO] Training Binary Classifier...
# [Binary Epoch 1/10] Loss: 0.6650, Accuracy: 0.6764, F1: 0.6745
# [Binary Epoch 2/10] Loss: 0.6082, Accuracy: 0.8473, F1: 0.8469
# [Binary Epoch 3/10] Loss: 0.5676, Accuracy: 0.8429, F1: 0.8424
# [Binary Epoch 4/10] Loss: 0.5334, Accuracy: 0.8709, F1: 0.8708
# [Binary Epoch 5/10] Loss: 0.5041, Accuracy: 0.8683, F1: 0.8681
# [Binary Epoch 6/10] Loss: 0.4772, Accuracy: 0.8918, F1: 0.8917
# [Binary Epoch 7/10] Loss: 0.4528, Accuracy: 0.9189, F1: 0.9189
# [Binary Epoch 8/10] Loss: 0.4304, Accuracy: 0.9277, F1: 0.9277
# [Binary Epoch 9/10] Loss: 0.4096, Accuracy: 0.9345, F1: 0.9345
# [Binary Epoch 10/10] Loss: 0.3903, Accuracy: 0.9428, F1: 0.9428
# Binary classifier model saved as 'binary_classifier.pt'
# Multi-class label distribution: {np.int64(0): np.int64(717), np.int64(1): np.int64(785), np.int64(2): np.int64(783), np.int64(3): np.int64(875)}
# Multi-class label distribution: {np.int64(0): np.int64(179), np.int64(1): np.int64(196), np.int64(2): np.int64(196), np.int64(3): np.int64(219)}
#
# [INFO] Training Multi Classifier...
#
# Epoch 1/5
# Train Loss: 1.2391, Train Accuracy: 0.4351, Train F1: 0.4314
# Val Loss: 0.7332, Val Accuracy: 0.7684, Val F1: 0.7555
# Class 0: F1=0.7740, Recall=0.8994
# Class 1: F1=0.8247, Recall=0.8520
# Class 2: F1=0.8357, Recall=0.9082
# Class 3: F1=0.6066, Recall=0.4612
# 새로운 최적 모델 저장!
#
# Epoch 2/5
# Train Loss: 0.5239, Train Accuracy: 0.8532, Train F1: 0.8524
# Val Loss: 0.4353, Val Accuracy: 0.8557, Val F1: 0.8535
# Class 0: F1=0.8669, Recall=0.8547
# Class 1: F1=0.8522, Recall=0.8827
# Class 2: F1=0.8967, Recall=0.9745
# Class 3: F1=0.8051, Recall=0.7260
# 새로운 최적 모델 저장!
#
# Epoch 3/5
# Train Loss: 0.3043, Train Accuracy: 0.9120, Train F1: 0.9118
# Val Loss: 0.3768, Val Accuracy: 0.8747, Val F1: 0.8741
# Class 0: F1=0.8541, Recall=0.8994
# Class 1: F1=0.8636, Recall=0.8724
# Class 2: F1=0.9397, Recall=0.9541
# Class 3: F1=0.8411, Recall=0.7854
# 새로운 최적 모델 저장!
#
# Epoch 4/5
# Train Loss: 0.2160, Train Accuracy: 0.9449, Train F1: 0.9449
# Val Loss: 0.3844, Val Accuracy: 0.8797, Val F1: 0.8795
# Class 0: F1=0.8571, Recall=0.9050
# Class 1: F1=0.8756, Recall=0.8622
# Class 2: F1=0.9370, Recall=0.9490
# Class 3: F1=0.8496, Recall=0.8128
# 새로운 최적 모델 저장!
#
# Epoch 5/5
# Train Loss: 0.1897, Train Accuracy: 0.9538, Train F1: 0.9537
# Val Loss: 0.3824, Val Accuracy: 0.8911, Val F1: 0.8914
# Class 0: F1=0.8771, Recall=0.8771
# Class 1: F1=0.8861, Recall=0.8929
# Class 2: F1=0.9403, Recall=0.9235
# Class 3: F1=0.8643, Recall=0.8721
# 새로운 최적 모델 저장!
#
# [INFO] Loading test set...
# Test set size: 500
#
# Predicting sample 1/500
# 일반대화 확률: 0.1095, 폭력대화 확률: 0.8905
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0087
# Class 1 (갈취 대화) 확률: 0.9635
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0100
# Class 3 (기타 괴롭힘 대화) 확률: 0.0178
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 2/500
# 일반대화 확률: 0.5817, 폭력대화 확률: 0.4183
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 3/500
# 일반대화 확률: 0.1007, 폭력대화 확률: 0.8993
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0819
# Class 1 (갈취 대화) 확률: 0.0183
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.8047
# Class 3 (기타 괴롭힘 대화) 확률: 0.0950
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 4/500
# 일반대화 확률: 0.1833, 폭력대화 확률: 0.8167
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0244
# Class 1 (갈취 대화) 확률: 0.0320
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0173
# Class 3 (기타 괴롭힘 대화) 확률: 0.9263
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 5/500
# 일반대화 확률: 0.2221, 폭력대화 확률: 0.7779
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0221
# Class 1 (갈취 대화) 확률: 0.0213
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0107
# Class 3 (기타 괴롭힘 대화) 확률: 0.9460
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 6/500
# 일반대화 확률: 0.1963, 폭력대화 확률: 0.8037
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9725
# Class 1 (갈취 대화) 확률: 0.0090
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0103
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 7/500
# 일반대화 확률: 0.3607, 폭력대화 확률: 0.6393
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9734
# Class 1 (갈취 대화) 확률: 0.0075
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0107
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 8/500
# 일반대화 확률: 0.1936, 폭력대화 확률: 0.8064
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0341
# Class 1 (갈취 대화) 확률: 0.7134
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0157
# Class 3 (기타 괴롭힘 대화) 확률: 0.2368
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 9/500
# 일반대화 확률: 0.5353, 폭력대화 확률: 0.4647
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 10/500
# 일반대화 확률: 0.2135, 폭력대화 확률: 0.7865
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0086
# Class 1 (갈취 대화) 확률: 0.9651
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0164
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 11/500
# 일반대화 확률: 0.4348, 폭력대화 확률: 0.5652
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 12/500
# 일반대화 확률: 0.3593, 폭력대화 확률: 0.6407
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0256
# Class 1 (갈취 대화) 확률: 0.0264
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0603
# Class 3 (기타 괴롭힘 대화) 확률: 0.8877
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 13/500
# 일반대화 확률: 0.4694, 폭력대화 확률: 0.5306
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 14/500
# 일반대화 확률: 0.2555, 폭력대화 확률: 0.7445
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0102
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9704
# Class 3 (기타 괴롭힘 대화) 확률: 0.0109
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 15/500
# 일반대화 확률: 0.3348, 폭력대화 확률: 0.6652
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0100
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9699
# Class 3 (기타 괴롭힘 대화) 확률: 0.0117
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 16/500
# 일반대화 확률: 0.3017, 폭력대화 확률: 0.6983
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9513
# Class 1 (갈취 대화) 확률: 0.0155
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0251
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 17/500
# 일반대화 확률: 0.4629, 폭력대화 확률: 0.5371
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 18/500
# 일반대화 확률: 0.3372, 폭력대화 확률: 0.6628
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0356
# Class 1 (갈취 대화) 확률: 0.0252
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0345
# Class 3 (기타 괴롭힘 대화) 확률: 0.9048
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 19/500
# 일반대화 확률: 0.3256, 폭력대화 확률: 0.6744
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0073
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0107
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 20/500
# 일반대화 확률: 0.5360, 폭력대화 확률: 0.4640
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 21/500
# 일반대화 확률: 0.3542, 폭력대화 확률: 0.6458
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9742
# Class 1 (갈취 대화) 확률: 0.0070
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0084
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 22/500
# 일반대화 확률: 0.2369, 폭력대화 확률: 0.7631
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2334
# Class 1 (갈취 대화) 확률: 0.0378
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0157
# Class 3 (기타 괴롭힘 대화) 확률: 0.7131
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 23/500
# 일반대화 확률: 0.3903, 폭력대화 확률: 0.6097
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0364
# Class 1 (갈취 대화) 확률: 0.0211
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.9305
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 24/500
# 일반대화 확률: 0.1844, 폭력대화 확률: 0.8156
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0085
# Class 1 (갈취 대화) 확률: 0.9648
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0172
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 25/500
# 일반대화 확률: 0.3523, 폭력대화 확률: 0.6477
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0083
# Class 1 (갈취 대화) 확률: 0.9648
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0173
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 26/500
# 일반대화 확률: 0.2285, 폭력대화 확률: 0.7715
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0097
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9712
# Class 3 (기타 괴롭힘 대화) 확률: 0.0108
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 27/500
# 일반대화 확률: 0.1479, 폭력대화 확률: 0.8521
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0331
# Class 1 (갈취 대화) 확률: 0.0290
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.9264
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 28/500
# 일반대화 확률: 0.2266, 폭력대화 확률: 0.7734
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0185
# Class 1 (갈취 대화) 확률: 0.0202
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0110
# Class 3 (기타 괴롭힘 대화) 확률: 0.9503
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 29/500
# 일반대화 확률: 0.3465, 폭력대화 확률: 0.6535
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0113
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9683
# Class 3 (기타 괴롭힘 대화) 확률: 0.0120
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 30/500
# 일반대화 확률: 0.2752, 폭력대화 확률: 0.7248
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.7343
# Class 1 (갈취 대화) 확률: 0.1228
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0121
# Class 3 (기타 괴롭힘 대화) 확률: 0.1309
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 31/500
# 일반대화 확률: 0.4859, 폭력대화 확률: 0.5141
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 32/500
# 일반대화 확률: 0.3161, 폭력대화 확률: 0.6839
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9712
# Class 1 (갈취 대화) 확률: 0.0095
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0110
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 33/500
# 일반대화 확률: 0.1798, 폭력대화 확률: 0.8202
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0232
# Class 1 (갈취 대화) 확률: 0.0225
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0194
# Class 3 (기타 괴롭힘 대화) 확률: 0.9349
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 34/500
# 일반대화 확률: 0.2711, 폭력대화 확률: 0.7289
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0199
# Class 1 (갈취 대화) 확률: 0.9248
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0127
# Class 3 (기타 괴롭힘 대화) 확률: 0.0426
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 35/500
# 일반대화 확률: 0.4023, 폭력대화 확률: 0.5977
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 36/500
# 일반대화 확률: 0.1117, 폭력대화 확률: 0.8883
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0179
# Class 1 (갈취 대화) 확률: 0.0210
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0114
# Class 3 (기타 괴롭힘 대화) 확률: 0.9497
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 37/500
# 일반대화 확률: 0.3768, 폭력대화 확률: 0.6232
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0393
# Class 1 (갈취 대화) 확률: 0.1107
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.8381
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 38/500
# 일반대화 확률: 0.1164, 폭력대화 확률: 0.8836
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9314
# Class 1 (갈취 대화) 확률: 0.0355
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0102
# Class 3 (기타 괴롭힘 대화) 확률: 0.0228
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 39/500
# 일반대화 확률: 0.2639, 폭력대화 확률: 0.7361
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9723
# Class 1 (갈취 대화) 확률: 0.0078
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.0102
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 40/500
# 일반대화 확률: 0.1991, 폭력대화 확률: 0.8009
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0092
# Class 1 (갈취 대화) 확률: 0.9635
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0101
# Class 3 (기타 괴롭힘 대화) 확률: 0.0172
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 41/500
# 일반대화 확률: 0.4459, 폭력대화 확률: 0.5541
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 42/500
# 일반대화 확률: 0.0854, 폭력대화 확률: 0.9146
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0132
# Class 1 (갈취 대화) 확률: 0.9418
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0110
# Class 3 (기타 괴롭힘 대화) 확률: 0.0341
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 43/500
# 일반대화 확률: 0.3182, 폭력대화 확률: 0.6818
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0107
# Class 1 (갈취 대화) 확률: 0.0137
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9631
# Class 3 (기타 괴롭힘 대화) 확률: 0.0125
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 44/500
# 일반대화 확률: 0.5312, 폭력대화 확률: 0.4688
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 45/500
# 일반대화 확률: 0.2409, 폭력대화 확률: 0.7591
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0178
# Class 1 (갈취 대화) 확률: 0.0204
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0121
# Class 3 (기타 괴롭힘 대화) 확률: 0.9497
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 46/500
# 일반대화 확률: 0.2617, 폭력대화 확률: 0.7383
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0103
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9701
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 47/500
# 일반대화 확률: 0.2336, 폭력대화 확률: 0.7664
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9691
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0072
# Class 3 (기타 괴롭힘 대화) 확률: 0.0155
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 48/500
# 일반대화 확률: 0.3865, 폭력대화 확률: 0.6135
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0310
# Class 1 (갈취 대화) 확률: 0.0204
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.9373
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 49/500
# 일반대화 확률: 0.3036, 폭력대화 확률: 0.6964
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0271
# Class 1 (갈취 대화) 확률: 0.0229
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0126
# Class 3 (기타 괴롭힘 대화) 확률: 0.9374
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 50/500
# 일반대화 확률: 0.2364, 폭력대화 확률: 0.7636
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0068
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0108
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 51/500
# 일반대화 확률: 0.4772, 폭력대화 확률: 0.5228
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 52/500
# 일반대화 확률: 0.3227, 폭력대화 확률: 0.6773
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0197
# Class 1 (갈취 대화) 확률: 0.0189
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.9502
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 53/500
# 일반대화 확률: 0.2311, 폭력대화 확률: 0.7689
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0090
# Class 1 (갈취 대화) 확률: 0.9645
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0096
# Class 3 (기타 괴롭힘 대화) 확률: 0.0168
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 54/500
# 일반대화 확률: 0.5725, 폭력대화 확률: 0.4275
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 55/500
# 일반대화 확률: 0.5580, 폭력대화 확률: 0.4420
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 56/500
# 일반대화 확률: 0.1760, 폭력대화 확률: 0.8240
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0229
# Class 1 (갈취 대화) 확률: 0.0228
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0102
# Class 3 (기타 괴롭힘 대화) 확률: 0.9440
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 57/500
# 일반대화 확률: 0.2463, 폭력대화 확률: 0.7537
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0352
# Class 1 (갈취 대화) 확률: 0.0232
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.9305
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 58/500
# 일반대화 확률: 0.4858, 폭력대화 확률: 0.5142
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 59/500
# 일반대화 확률: 0.0567, 폭력대화 확률: 0.9433
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0185
# Class 1 (갈취 대화) 확률: 0.0172
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0122
# Class 3 (기타 괴롭힘 대화) 확률: 0.9522
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 60/500
# 일반대화 확률: 0.3102, 폭력대화 확률: 0.6898
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0238
# Class 1 (갈취 대화) 확률: 0.0175
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0136
# Class 3 (기타 괴롭힘 대화) 확률: 0.9450
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 61/500
# 일반대화 확률: 0.3540, 폭력대화 확률: 0.6460
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0096
# Class 1 (갈취 대화) 확률: 0.9628
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0177
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 62/500
# 일반대화 확률: 0.4291, 폭력대화 확률: 0.5709
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 63/500
# 일반대화 확률: 0.5516, 폭력대화 확률: 0.4484
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 64/500
# 일반대화 확률: 0.1878, 폭력대화 확률: 0.8122
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0239
# Class 1 (갈취 대화) 확률: 0.0166
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0203
# Class 3 (기타 괴롭힘 대화) 확률: 0.9391
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 65/500
# 일반대화 확률: 0.4323, 폭력대화 확률: 0.5677
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 66/500
# 일반대화 확률: 0.2072, 폭력대화 확률: 0.7928
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9741
# Class 1 (갈취 대화) 확률: 0.0073
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0107
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 67/500
# 일반대화 확률: 0.1146, 폭력대화 확률: 0.8854
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2761
# Class 1 (갈취 대화) 확률: 0.0452
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0167
# Class 3 (기타 괴롭힘 대화) 확률: 0.6621
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 68/500
# 일반대화 확률: 0.3655, 폭력대화 확률: 0.6345
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0252
# Class 1 (갈취 대화) 확률: 0.0252
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0120
# Class 3 (기타 괴롭힘 대화) 확률: 0.9376
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 69/500
# 일반대화 확률: 0.5279, 폭력대화 확률: 0.4721
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 70/500
# 일반대화 확률: 0.1034, 폭력대화 확률: 0.8966
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.4250
# Class 1 (갈취 대화) 확률: 0.5022
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0261
# Class 3 (기타 괴롭힘 대화) 확률: 0.0467
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 71/500
# 일반대화 확률: 0.1801, 폭력대화 확률: 0.8199
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.4496
# Class 1 (갈취 대화) 확률: 0.0252
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0707
# Class 3 (기타 괴롭힘 대화) 확률: 0.4545
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 72/500
# 일반대화 확률: 0.4677, 폭력대화 확률: 0.5323
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 73/500
# 일반대화 확률: 0.1702, 폭력대화 확률: 0.8298
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0203
# Class 1 (갈취 대화) 확률: 0.0178
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0118
# Class 3 (기타 괴롭힘 대화) 확률: 0.9501
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 74/500
# 일반대화 확률: 0.4436, 폭력대화 확률: 0.5564
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 75/500
# 일반대화 확률: 0.3110, 폭력대화 확률: 0.6890
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9729
# Class 1 (갈취 대화) 확률: 0.0077
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0074
# Class 3 (기타 괴롭힘 대화) 확률: 0.0120
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 76/500
# 일반대화 확률: 0.2937, 폭력대화 확률: 0.7063
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0096
# Class 1 (갈취 대화) 확률: 0.0083
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9705
# Class 3 (기타 괴롭힘 대화) 확률: 0.0115
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 77/500
# 일반대화 확률: 0.2966, 폭력대화 확률: 0.7034
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0357
# Class 1 (갈취 대화) 확률: 0.0133
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.8909
# Class 3 (기타 괴롭힘 대화) 확률: 0.0601
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 78/500
# 일반대화 확률: 0.4180, 폭력대화 확률: 0.5820
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 79/500
# 일반대화 확률: 0.5497, 폭력대화 확률: 0.4503
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 80/500
# 일반대화 확률: 0.3684, 폭력대화 확률: 0.6316
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.3815
# Class 1 (갈취 대화) 확률: 0.0261
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0816
# Class 3 (기타 괴롭힘 대화) 확률: 0.5109
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 81/500
# 일반대화 확률: 0.1209, 폭력대화 확률: 0.8791
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0261
# Class 1 (갈취 대화) 확률: 0.8380
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0160
# Class 3 (기타 괴롭힘 대화) 확률: 0.1199
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 82/500
# 일반대화 확률: 0.3487, 폭력대화 확률: 0.6513
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9664
# Class 1 (갈취 대화) 확률: 0.0104
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0073
# Class 3 (기타 괴롭힘 대화) 확률: 0.0159
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 83/500
# 일반대화 확률: 0.5177, 폭력대화 확률: 0.4823
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 84/500
# 일반대화 확률: 0.3018, 폭력대화 확률: 0.6982
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9731
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0079
# Class 3 (기타 괴롭힘 대화) 확률: 0.0109
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 85/500
# 일반대화 확률: 0.3320, 폭력대화 확률: 0.6680
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0413
# Class 1 (갈취 대화) 확률: 0.0321
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0117
# Class 3 (기타 괴롭힘 대화) 확률: 0.9149
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 86/500
# 일반대화 확률: 0.5800, 폭력대화 확률: 0.4200
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 87/500
# 일반대화 확률: 0.2971, 폭력대화 확률: 0.7029
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8290
# Class 1 (갈취 대화) 확률: 0.1187
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0165
# Class 3 (기타 괴롭힘 대화) 확률: 0.0358
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 88/500
# 일반대화 확률: 0.1848, 폭력대화 확률: 0.8152
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0276
# Class 1 (갈취 대화) 확률: 0.0190
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0140
# Class 3 (기타 괴롭힘 대화) 확률: 0.9394
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 89/500
# 일반대화 확률: 0.1223, 폭력대화 확률: 0.8777
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0152
# Class 1 (갈취 대화) 확률: 0.9347
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0106
# Class 3 (기타 괴롭힘 대화) 확률: 0.0395
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 90/500
# 일반대화 확률: 0.3003, 폭력대화 확률: 0.6997
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0095
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9708
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 91/500
# 일반대화 확률: 0.4727, 폭력대화 확률: 0.5273
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 92/500
# 일반대화 확률: 0.4922, 폭력대화 확률: 0.5078
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 93/500
# 일반대화 확률: 0.1101, 폭력대화 확률: 0.8899
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0069
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0085
# Class 3 (기타 괴롭힘 대화) 확률: 0.0103
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 94/500
# 일반대화 확률: 0.1250, 폭력대화 확률: 0.8750
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0176
# Class 1 (갈취 대화) 확률: 0.0175
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.9529
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 95/500
# 일반대화 확률: 0.2482, 폭력대화 확률: 0.7518
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0212
# Class 1 (갈취 대화) 확률: 0.0165
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0134
# Class 3 (기타 괴롭힘 대화) 확률: 0.9489
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 96/500
# 일반대화 확률: 0.1977, 폭력대화 확률: 0.8023
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0102
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9700
# Class 3 (기타 괴롭힘 대화) 확률: 0.0114
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 97/500
# 일반대화 확률: 0.3178, 폭력대화 확률: 0.6822
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0382
# Class 1 (갈취 대화) 확률: 0.7227
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0267
# Class 3 (기타 괴롭힘 대화) 확률: 0.2124
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 98/500
# 일반대화 확률: 0.3774, 폭력대화 확률: 0.6226
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0116
# Class 1 (갈취 대화) 확률: 0.0091
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9669
# Class 3 (기타 괴롭힘 대화) 확률: 0.0124
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 99/500
# 일반대화 확률: 0.1576, 폭력대화 확률: 0.8424
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8853
# Class 1 (갈취 대화) 확률: 0.0754
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0146
# Class 3 (기타 괴롭힘 대화) 확률: 0.0247
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 100/500
# 일반대화 확률: 0.2625, 폭력대화 확률: 0.7375
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9169
# Class 1 (갈취 대화) 확률: 0.0160
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0421
# Class 3 (기타 괴롭힘 대화) 확률: 0.0250
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 101/500
# 일반대화 확률: 0.1549, 폭력대화 확률: 0.8451
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0092
# Class 1 (갈취 대화) 확률: 0.9623
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0094
# Class 3 (기타 괴롭힘 대화) 확률: 0.0190
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 102/500
# 일반대화 확률: 0.3139, 폭력대화 확률: 0.6861
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0086
# Class 1 (갈취 대화) 확률: 0.9652
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0094
# Class 3 (기타 괴롭힘 대화) 확률: 0.0168
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 103/500
# 일반대화 확률: 0.2384, 폭력대화 확률: 0.7616
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0342
# Class 1 (갈취 대화) 확률: 0.0257
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0538
# Class 3 (기타 괴롭힘 대화) 확률: 0.8864
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 104/500
# 일반대화 확률: 0.2836, 폭력대화 확률: 0.7164
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9742
# Class 1 (갈취 대화) 확률: 0.0076
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0100
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 105/500
# 일반대화 확률: 0.3535, 폭력대화 확률: 0.6465
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8919
# Class 1 (갈취 대화) 확률: 0.0135
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0161
# Class 3 (기타 괴롭힘 대화) 확률: 0.0785
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 106/500
# 일반대화 확률: 0.4350, 폭력대화 확률: 0.5650
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 107/500
# 일반대화 확률: 0.3741, 폭력대화 확률: 0.6259
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0101
# Class 1 (갈취 대화) 확률: 0.0087
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9698
# Class 3 (기타 괴롭힘 대화) 확률: 0.0114
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 108/500
# 일반대화 확률: 0.3767, 폭력대화 확률: 0.6233
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0555
# Class 1 (갈취 대화) 확률: 0.0386
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0113
# Class 3 (기타 괴롭힘 대화) 확률: 0.8946
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 109/500
# 일반대화 확률: 0.3309, 폭력대화 확률: 0.6691
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0203
# Class 1 (갈취 대화) 확률: 0.0213
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0158
# Class 3 (기타 괴롭힘 대화) 확률: 0.9426
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 110/500
# 일반대화 확률: 0.4744, 폭력대화 확률: 0.5256
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 111/500
# 일반대화 확률: 0.2542, 폭력대화 확률: 0.7458
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0544
# Class 1 (갈취 대화) 확률: 0.0339
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0140
# Class 3 (기타 괴롭힘 대화) 확률: 0.8977
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 112/500
# 일반대화 확률: 0.3073, 폭력대화 확률: 0.6927
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9741
# Class 1 (갈취 대화) 확률: 0.0073
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0106
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 113/500
# 일반대화 확률: 0.3906, 폭력대화 확률: 0.6094
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1047
# Class 1 (갈취 대화) 확률: 0.8103
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0619
# Class 3 (기타 괴롭힘 대화) 확률: 0.0231
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 114/500
# 일반대화 확률: 0.3755, 폭력대화 확률: 0.6245
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0108
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9675
# Class 3 (기타 괴롭힘 대화) 확률: 0.0131
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 115/500
# 일반대화 확률: 0.3418, 폭력대화 확률: 0.6582
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0375
# Class 1 (갈취 대화) 확률: 0.2262
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0150
# Class 3 (기타 괴롭힘 대화) 확률: 0.7214
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 116/500
# 일반대화 확률: 0.3907, 폭력대화 확률: 0.6093
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0089
# Class 1 (갈취 대화) 확률: 0.9647
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0169
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 117/500
# 일반대화 확률: 0.1445, 폭력대화 확률: 0.8555
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0119
# Class 1 (갈취 대화) 확률: 0.9310
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0182
# Class 3 (기타 괴롭힘 대화) 확률: 0.0390
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 118/500
# 일반대화 확률: 0.3748, 폭력대화 확률: 0.6252
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0098
# Class 1 (갈취 대화) 확률: 0.0088
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9701
# Class 3 (기타 괴롭힘 대화) 확률: 0.0113
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 119/500
# 일반대화 확률: 0.2457, 폭력대화 확률: 0.7543
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0141
# Class 1 (갈취 대화) 확률: 0.0114
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9485
# Class 3 (기타 괴롭힘 대화) 확률: 0.0259
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 120/500
# 일반대화 확률: 0.2976, 폭력대화 확률: 0.7024
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0088
# Class 1 (갈취 대화) 확률: 0.9653
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0160
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 121/500
# 일반대화 확률: 0.3985, 폭력대화 확률: 0.6015
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0268
# Class 1 (갈취 대화) 확률: 0.0124
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9217
# Class 3 (기타 괴롭힘 대화) 확률: 0.0391
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 122/500
# 일반대화 확률: 0.2550, 폭력대화 확률: 0.7450
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0236
# Class 1 (갈취 대화) 확률: 0.0317
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0121
# Class 3 (기타 괴롭힘 대화) 확률: 0.9325
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 123/500
# 일반대화 확률: 0.1301, 폭력대화 확률: 0.8699
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0478
# Class 1 (갈취 대화) 확률: 0.8764
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0125
# Class 3 (기타 괴롭힘 대화) 확률: 0.0633
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 124/500
# 일반대화 확률: 0.3557, 폭력대화 확률: 0.6443
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0090
# Class 1 (갈취 대화) 확률: 0.9643
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0169
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 125/500
# 일반대화 확률: 0.5336, 폭력대화 확률: 0.4664
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 126/500
# 일반대화 확률: 0.3087, 폭력대화 확률: 0.6913
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0107
# Class 1 (갈취 대화) 확률: 0.9603
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0102
# Class 3 (기타 괴롭힘 대화) 확률: 0.0188
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 127/500
# 일반대화 확률: 0.4419, 폭력대화 확률: 0.5581
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 128/500
# 일반대화 확률: 0.6752, 폭력대화 확률: 0.3248
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 129/500
# 일반대화 확률: 0.2453, 폭력대화 확률: 0.7547
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0090
# Class 1 (갈취 대화) 확률: 0.9643
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0167
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 130/500
# 일반대화 확률: 0.2292, 폭력대화 확률: 0.7708
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0216
# Class 1 (갈취 대화) 확률: 0.0179
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0128
# Class 3 (기타 괴롭힘 대화) 확률: 0.9477
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 131/500
# 일반대화 확률: 0.1374, 폭력대화 확률: 0.8626
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0248
# Class 1 (갈취 대화) 확률: 0.0195
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0108
# Class 3 (기타 괴롭힘 대화) 확률: 0.9449
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 132/500
# 일반대화 확률: 0.3680, 폭력대화 확률: 0.6320
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0207
# Class 1 (갈취 대화) 확률: 0.0169
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.9508
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 133/500
# 일반대화 확률: 0.4167, 폭력대화 확률: 0.5833
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 134/500
# 일반대화 확률: 0.2648, 폭력대화 확률: 0.7352
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0167
# Class 1 (갈취 대화) 확률: 0.0182
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.9540
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 135/500
# 일반대화 확률: 0.2403, 폭력대화 확률: 0.7597
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0130
# Class 1 (갈취 대화) 확률: 0.9527
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0096
# Class 3 (기타 괴롭힘 대화) 확률: 0.0247
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 136/500
# 일반대화 확률: 0.3271, 폭력대화 확률: 0.6729
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9737
# Class 1 (갈취 대화) 확률: 0.0072
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0112
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 137/500
# 일반대화 확률: 0.3356, 폭력대화 확률: 0.6644
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9597
# Class 1 (갈취 대화) 확률: 0.0134
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0067
# Class 3 (기타 괴롭힘 대화) 확률: 0.0202
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 138/500
# 일반대화 확률: 0.2410, 폭력대화 확률: 0.7590
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9740
# Class 1 (갈취 대화) 확률: 0.0076
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0103
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 139/500
# 일반대화 확률: 0.1157, 폭력대화 확률: 0.8843
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0189
# Class 1 (갈취 대화) 확률: 0.0182
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0126
# Class 3 (기타 괴롭힘 대화) 확률: 0.9503
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 140/500
# 일반대화 확률: 0.2677, 폭력대화 확률: 0.7323
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0484
# Class 1 (갈취 대화) 확률: 0.0299
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1070
# Class 3 (기타 괴롭힘 대화) 확률: 0.8148
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 141/500
# 일반대화 확률: 0.1655, 폭력대화 확률: 0.8345
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9690
# Class 1 (갈취 대화) 확률: 0.0078
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0150
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 142/500
# 일반대화 확률: 0.1967, 폭력대화 확률: 0.8033
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0296
# Class 1 (갈취 대화) 확률: 0.0272
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0198
# Class 3 (기타 괴롭힘 대화) 확률: 0.9234
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 143/500
# 일반대화 확률: 0.1665, 폭력대화 확률: 0.8335
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0086
# Class 1 (갈취 대화) 확률: 0.9652
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.0165
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 144/500
# 일반대화 확률: 0.3571, 폭력대화 확률: 0.6429
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0231
# Class 1 (갈취 대화) 확률: 0.0175
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0113
# Class 3 (기타 괴롭힘 대화) 확률: 0.9481
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 145/500
# 일반대화 확률: 0.3571, 폭력대화 확률: 0.6429
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0681
# Class 1 (갈취 대화) 확률: 0.0164
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.8842
# Class 3 (기타 괴롭힘 대화) 확률: 0.0314
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 146/500
# 일반대화 확률: 0.5093, 폭력대화 확률: 0.4907
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 147/500
# 일반대화 확률: 0.3667, 폭력대화 확률: 0.6333
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9745
# Class 1 (갈취 대화) 확률: 0.0070
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0103
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 148/500
# 일반대화 확률: 0.4118, 폭력대화 확률: 0.5882
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 149/500
# 일반대화 확률: 0.3373, 폭력대화 확률: 0.6627
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0824
# Class 1 (갈취 대화) 확률: 0.0249
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0163
# Class 3 (기타 괴롭힘 대화) 확률: 0.8764
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 150/500
# 일반대화 확률: 0.1074, 폭력대화 확률: 0.8926
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0089
# Class 1 (갈취 대화) 확률: 0.9639
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.0175
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 151/500
# 일반대화 확률: 0.5206, 폭력대화 확률: 0.4794
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 152/500
# 일반대화 확률: 0.3473, 폭력대화 확률: 0.6527
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1685
# Class 1 (갈취 대화) 확률: 0.0415
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0128
# Class 3 (기타 괴롭힘 대화) 확률: 0.7773
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 153/500
# 일반대화 확률: 0.4728, 폭력대화 확률: 0.5272
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 154/500
# 일반대화 확률: 0.2744, 폭력대화 확률: 0.7256
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0095
# Class 1 (갈취 대화) 확률: 0.9627
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.0163
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 155/500
# 일반대화 확률: 0.3067, 폭력대화 확률: 0.6933
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0355
# Class 1 (갈취 대화) 확률: 0.0262
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0787
# Class 3 (기타 괴롭힘 대화) 확률: 0.8596
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 156/500
# 일반대화 확률: 0.2074, 폭력대화 확률: 0.7926
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0200
# Class 1 (갈취 대화) 확률: 0.0229
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.9456
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 157/500
# 일반대화 확률: 0.2676, 폭력대화 확률: 0.7324
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9745
# Class 1 (갈취 대화) 확률: 0.0073
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 158/500
# 일반대화 확률: 0.3762, 폭력대화 확률: 0.6238
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0100
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9707
# Class 3 (기타 괴롭힘 대화) 확률: 0.0109
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 159/500
# 일반대화 확률: 0.3314, 폭력대화 확률: 0.6686
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0197
# Class 1 (갈취 대화) 확률: 0.0169
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0123
# Class 3 (기타 괴롭힘 대화) 확률: 0.9512
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 160/500
# 일반대화 확률: 0.2488, 폭력대화 확률: 0.7512
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0552
# Class 1 (갈취 대화) 확률: 0.0231
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0128
# Class 3 (기타 괴롭힘 대화) 확률: 0.9089
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 161/500
# 일반대화 확률: 0.3758, 폭력대화 확률: 0.6242
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9745
# Class 1 (갈취 대화) 확률: 0.0069
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0084
# Class 3 (기타 괴롭힘 대화) 확률: 0.0102
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 162/500
# 일반대화 확률: 0.2848, 폭력대화 확률: 0.7152
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0189
# Class 1 (갈취 대화) 확률: 0.0184
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.9512
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 163/500
# 일반대화 확률: 0.7253, 폭력대화 확률: 0.2747
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 164/500
# 일반대화 확률: 0.3404, 폭력대화 확률: 0.6596
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9744
# Class 1 (갈취 대화) 확률: 0.0071
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0106
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 165/500
# 일반대화 확률: 0.1105, 폭력대화 확률: 0.8895
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0236
# Class 1 (갈취 대화) 확률: 0.0186
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0130
# Class 3 (기타 괴롭힘 대화) 확률: 0.9448
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 166/500
# 일반대화 확률: 0.2317, 폭력대화 확률: 0.7683
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0198
# Class 1 (갈취 대화) 확률: 0.0175
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.9508
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 167/500
# 일반대화 확률: 0.3410, 폭력대화 확률: 0.6590
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0112
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9690
# Class 3 (기타 괴롭힘 대화) 확률: 0.0112
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 168/500
# 일반대화 확률: 0.2036, 폭력대화 확률: 0.7964
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0271
# Class 1 (갈취 대화) 확률: 0.0224
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0150
# Class 3 (기타 괴롭힘 대화) 확률: 0.9354
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 169/500
# 일반대화 확률: 0.1434, 폭력대화 확률: 0.8566
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0214
# Class 1 (갈취 대화) 확률: 0.0174
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0113
# Class 3 (기타 괴롭힘 대화) 확률: 0.9499
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 170/500
# 일반대화 확률: 0.1159, 폭력대화 확률: 0.8841
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0085
# Class 1 (갈취 대화) 확률: 0.9621
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0096
# Class 3 (기타 괴롭힘 대화) 확률: 0.0197
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 171/500
# 일반대화 확률: 0.4175, 폭력대화 확률: 0.5825
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 172/500
# 일반대화 확률: 0.2462, 폭력대화 확률: 0.7538
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0111
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9694
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 173/500
# 일반대화 확률: 0.4217, 폭력대화 확률: 0.5783
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 174/500
# 일반대화 확률: 0.2285, 폭력대화 확률: 0.7715
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0203
# Class 1 (갈취 대화) 확률: 0.0217
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0109
# Class 3 (기타 괴롭힘 대화) 확률: 0.9471
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 175/500
# 일반대화 확률: 0.4809, 폭력대화 확률: 0.5191
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 176/500
# 일반대화 확률: 0.4700, 폭력대화 확률: 0.5300
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 177/500
# 일반대화 확률: 0.4656, 폭력대화 확률: 0.5344
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 178/500
# 일반대화 확률: 0.4704, 폭력대화 확률: 0.5296
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 179/500
# 일반대화 확률: 0.3867, 폭력대화 확률: 0.6133
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0383
# Class 1 (갈취 대화) 확률: 0.8600
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0123
# Class 3 (기타 괴롭힘 대화) 확률: 0.0895
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 180/500
# 일반대화 확률: 0.4834, 폭력대화 확률: 0.5166
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 181/500
# 일반대화 확률: 0.3480, 폭력대화 확률: 0.6520
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0105
# Class 1 (갈취 대화) 확률: 0.0087
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9698
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 182/500
# 일반대화 확률: 0.1149, 폭력대화 확률: 0.8851
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0852
# Class 1 (갈취 대화) 확률: 0.0284
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.8720
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 183/500
# 일반대화 확률: 0.2358, 폭력대화 확률: 0.7642
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0096
# Class 1 (갈취 대화) 확률: 0.0112
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9682
# Class 3 (기타 괴롭힘 대화) 확률: 0.0110
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 184/500
# 일반대화 확률: 0.3721, 폭력대화 확률: 0.6279
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0505
# Class 1 (갈취 대화) 확률: 0.0272
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.6336
# Class 3 (기타 괴롭힘 대화) 확률: 0.2887
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 185/500
# 일반대화 확률: 0.0814, 폭력대화 확률: 0.9186
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9597
# Class 1 (갈취 대화) 확률: 0.0092
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0229
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 186/500
# 일반대화 확률: 0.2100, 폭력대화 확률: 0.7900
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0416
# Class 1 (갈취 대화) 확률: 0.0317
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0928
# Class 3 (기타 괴롭힘 대화) 확률: 0.8338
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 187/500
# 일반대화 확률: 0.4221, 폭력대화 확률: 0.5779
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 188/500
# 일반대화 확률: 0.3043, 폭력대화 확률: 0.6957
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0072
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 189/500
# 일반대화 확률: 0.4443, 폭력대화 확률: 0.5557
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 190/500
# 일반대화 확률: 0.2177, 폭력대화 확률: 0.7823
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9091
# Class 1 (갈취 대화) 확률: 0.0183
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0645
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 191/500
# 일반대화 확률: 0.3902, 폭력대화 확률: 0.6098
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9740
# Class 1 (갈취 대화) 확률: 0.0069
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0108
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 192/500
# 일반대화 확률: 0.0475, 폭력대화 확률: 0.9525
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0239
# Class 1 (갈취 대화) 확률: 0.0195
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0128
# Class 3 (기타 괴롭힘 대화) 확률: 0.9438
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 193/500
# 일반대화 확률: 0.3196, 폭력대화 확률: 0.6804
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0088
# Class 1 (갈취 대화) 확률: 0.9644
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.0171
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 194/500
# 일반대화 확률: 0.2091, 폭력대화 확률: 0.7909
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0384
# Class 1 (갈취 대화) 확률: 0.0230
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0181
# Class 3 (기타 괴롭힘 대화) 확률: 0.9204
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 195/500
# 일반대화 확률: 0.0864, 폭력대화 확률: 0.9136
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0083
# Class 1 (갈취 대화) 확률: 0.9640
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0104
# Class 3 (기타 괴롭힘 대화) 확률: 0.0172
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 196/500
# 일반대화 확률: 0.1710, 폭력대화 확률: 0.8290
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8515
# ...
#
# Predicting sample 425/500
# 일반대화 확률: 0.1040, 폭력대화 확률: 0.8960
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0199
# Class 1 (갈취 대화) 확률: 0.0170
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0115
# Class 3 (기타 괴롭힘 대화) 확률: 0.9516
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 426/500
# 일반대화 확률: 0.2969, 폭력대화 확률: 0.7031
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0087
# Class 1 (갈취 대화) 확률: 0.9640
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0098
# Class 3 (기타 괴롭힘 대화) 확률: 0.0176
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 427/500
# 일반대화 확률: 0.3057, 폭력대화 확률: 0.6943
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.4046
# Class 1 (갈취 대화) 확률: 0.5181
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0196
# Class 3 (기타 괴롭힘 대화) 확률: 0.0576
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 428/500
# 일반대화 확률: 0.3662, 폭력대화 확률: 0.6338
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0098
# Class 1 (갈취 대화) 확률: 0.0087
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9705
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 429/500
# 일반대화 확률: 0.5051, 폭력대화 확률: 0.4949
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 430/500
# 일반대화 확률: 0.4868, 폭력대화 확률: 0.5132
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 431/500
# 일반대화 확률: 0.3381, 폭력대화 확률: 0.6619
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0186
# Class 1 (갈취 대화) 확률: 0.0189
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0109
# Class 3 (기타 괴롭힘 대화) 확률: 0.9516
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 432/500
# 일반대화 확률: 0.3037, 폭력대화 확률: 0.6963
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0395
# Class 1 (갈취 대화) 확률: 0.0220
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0122
# Class 3 (기타 괴롭힘 대화) 확률: 0.9263
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 433/500
# 일반대화 확률: 0.3278, 폭력대화 확률: 0.6722
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8211
# Class 1 (갈취 대화) 확률: 0.1276
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.0369
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 434/500
# 일반대화 확률: 0.5339, 폭력대화 확률: 0.4661
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 435/500
# 일반대화 확률: 0.2783, 폭력대화 확률: 0.7217
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0514
# Class 1 (갈취 대화) 확률: 0.2700
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0156
# Class 3 (기타 괴롭힘 대화) 확률: 0.6630
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 436/500
# 일반대화 확률: 0.1532, 폭력대화 확률: 0.8468
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0221
# Class 1 (갈취 대화) 확률: 0.0195
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.9464
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 437/500
# 일반대화 확률: 0.4216, 폭력대화 확률: 0.5784
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 438/500
# 일반대화 확률: 0.2213, 폭력대화 확률: 0.7787
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1686
# Class 1 (갈취 대화) 확률: 0.0587
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.2888
# Class 3 (기타 괴롭힘 대화) 확률: 0.4839
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 439/500
# 일반대화 확률: 0.2488, 폭력대화 확률: 0.7512
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0275
# Class 1 (갈취 대화) 확률: 0.0357
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0119
# Class 3 (기타 괴롭힘 대화) 확률: 0.9250
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 440/500
# 일반대화 확률: 0.4783, 폭력대화 확률: 0.5217
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 441/500
# 일반대화 확률: 0.3988, 폭력대화 확률: 0.6012
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0201
# Class 1 (갈취 대화) 확률: 0.0174
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0114
# Class 3 (기타 괴롭힘 대화) 확률: 0.9510
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 442/500
# 일반대화 확률: 0.4395, 폭력대화 확률: 0.5605
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 443/500
# 일반대화 확률: 0.4371, 폭력대화 확률: 0.5629
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 444/500
# 일반대화 확률: 0.4915, 폭력대화 확률: 0.5085
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 445/500
# 일반대화 확률: 0.3199, 폭력대화 확률: 0.6801
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0398
# Class 1 (갈취 대화) 확률: 0.1435
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.8023
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 446/500
# 일반대화 확률: 0.2060, 폭력대화 확률: 0.7940
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0110
# Class 1 (갈취 대화) 확률: 0.0098
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9640
# Class 3 (기타 괴롭힘 대화) 확률: 0.0151
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 447/500
# 일반대화 확률: 0.3498, 폭력대화 확률: 0.6502
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9673
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0162
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 448/500
# 일반대화 확률: 0.3033, 폭력대화 확률: 0.6967
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0112
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9695
# Class 3 (기타 괴롭힘 대화) 확률: 0.0108
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 449/500
# 일반대화 확률: 0.2270, 폭력대화 확률: 0.7730
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0098
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9708
# Class 3 (기타 괴롭힘 대화) 확률: 0.0110
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 450/500
# 일반대화 확률: 0.2943, 폭력대화 확률: 0.7057
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0344
# Class 1 (갈취 대화) 확률: 0.1049
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0275
# Class 3 (기타 괴롭힘 대화) 확률: 0.8332
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 451/500
# 일반대화 확률: 0.1982, 폭력대화 확률: 0.8018
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0538
# Class 1 (갈취 대화) 확률: 0.5690
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0474
# Class 3 (기타 괴롭힘 대화) 확률: 0.3298
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 452/500
# 일반대화 확률: 0.4084, 폭력대화 확률: 0.5916
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 453/500
# 일반대화 확률: 0.4586, 폭력대화 확률: 0.5414
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 454/500
# 일반대화 확률: 0.3423, 폭력대화 확률: 0.6577
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9028
# Class 1 (갈취 대화) 확률: 0.0162
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0092
# Class 3 (기타 괴롭힘 대화) 확률: 0.0718
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 455/500
# 일반대화 확률: 0.4195, 폭력대화 확률: 0.5805
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 456/500
# 일반대화 확률: 0.2106, 폭력대화 확률: 0.7894
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0172
# Class 1 (갈취 대화) 확률: 0.9347
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0117
# Class 3 (기타 괴롭힘 대화) 확률: 0.0365
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 457/500
# 일반대화 확률: 0.3986, 폭력대화 확률: 0.6014
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0102
# Class 1 (갈취 대화) 확률: 0.0083
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9703
# Class 3 (기타 괴롭힘 대화) 확률: 0.0111
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 458/500
# 일반대화 확률: 0.3346, 폭력대화 확률: 0.6654
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1655
# Class 1 (갈취 대화) 확률: 0.0297
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1439
# Class 3 (기타 괴롭힘 대화) 확률: 0.6608
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 459/500
# 일반대화 확률: 0.3372, 폭력대화 확률: 0.6628
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0095
# Class 1 (갈취 대화) 확률: 0.9621
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0188
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 460/500
# 일반대화 확률: 0.3949, 폭력대화 확률: 0.6051
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0243
# Class 1 (갈취 대화) 확률: 0.9356
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.0289
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 461/500
# 일반대화 확률: 0.5048, 폭력대화 확률: 0.4952
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 462/500
# 일반대화 확률: 0.4987, 폭력대화 확률: 0.5013
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 463/500
# 일반대화 확률: 0.4047, 폭력대화 확률: 0.5953
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 464/500
# 일반대화 확률: 0.4403, 폭력대화 확률: 0.5597
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 465/500
# 일반대화 확률: 0.2246, 폭력대화 확률: 0.7754
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0105
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9695
# Class 3 (기타 괴롭힘 대화) 확률: 0.0114
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 466/500
# 일반대화 확률: 0.2589, 폭력대화 확률: 0.7411
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0267
# Class 1 (갈취 대화) 확률: 0.0666
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0117
# Class 3 (기타 괴롭힘 대화) 확률: 0.8950
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 467/500
# 일반대화 확률: 0.4261, 폭력대화 확률: 0.5739
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 468/500
# 일반대화 확률: 0.2942, 폭력대화 확률: 0.7058
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0098
# Class 1 (갈취 대화) 확률: 0.0089
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9691
# Class 3 (기타 괴롭힘 대화) 확률: 0.0121
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 469/500
# 일반대화 확률: 0.5630, 폭력대화 확률: 0.4370
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 470/500
# 일반대화 확률: 0.2827, 폭력대화 확률: 0.7173
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0070
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 471/500
# 일반대화 확률: 0.4315, 폭력대화 확률: 0.5685
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 472/500
# 일반대화 확률: 0.3775, 폭력대화 확률: 0.6225
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0083
# Class 1 (갈취 대화) 확률: 0.9649
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0100
# Class 3 (기타 괴롭힘 대화) 확률: 0.0168
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 473/500
# 일반대화 확률: 0.4156, 폭력대화 확률: 0.5844
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 474/500
# 일반대화 확률: 0.4083, 폭력대화 확률: 0.5917
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 475/500
# 일반대화 확률: 0.5189, 폭력대화 확률: 0.4811
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 476/500
# 일반대화 확률: 0.3730, 폭력대화 확률: 0.6270
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0102
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9709
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 477/500
# 일반대화 확률: 0.3199, 폭력대화 확률: 0.6801
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0082
# Class 1 (갈취 대화) 확률: 0.9637
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0098
# Class 3 (기타 괴롭힘 대화) 확률: 0.0182
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 478/500
# 일반대화 확률: 0.4077, 폭력대화 확률: 0.5923
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 479/500
# 일반대화 확률: 0.2312, 폭력대화 확률: 0.7688
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0201
# Class 1 (갈취 대화) 확률: 0.0365
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0264
# Class 3 (기타 괴롭힘 대화) 확률: 0.9170
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 480/500
# 일반대화 확률: 0.3907, 폭력대화 확률: 0.6093
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0109
# Class 1 (갈취 대화) 확률: 0.0089
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9681
# Class 3 (기타 괴롭힘 대화) 확률: 0.0121
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 481/500
# 일반대화 확률: 0.5429, 폭력대화 확률: 0.4571
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 482/500
# 일반대화 확률: 0.0839, 폭력대화 확률: 0.9161
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0205
# Class 1 (갈취 대화) 확률: 0.0188
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.9495
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 483/500
# 일반대화 확률: 0.1630, 폭력대화 확률: 0.8370
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0094
# Class 1 (갈취 대화) 확률: 0.9637
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0096
# Class 3 (기타 괴롭힘 대화) 확률: 0.0173
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 484/500
# 일반대화 확률: 0.3296, 폭력대화 확률: 0.6704
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9728
# Class 1 (갈취 대화) 확률: 0.0079
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0076
# Class 3 (기타 괴롭힘 대화) 확률: 0.0117
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 485/500
# 일반대화 확률: 0.4087, 폭력대화 확률: 0.5913
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 486/500
# 일반대화 확률: 0.1125, 폭력대화 확률: 0.8875
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0203
# Class 1 (갈취 대화) 확률: 0.0191
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0116
# Class 3 (기타 괴롭힘 대화) 확률: 0.9490
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 487/500
# 일반대화 확률: 0.1601, 폭력대화 확률: 0.8399
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0187
# Class 1 (갈취 대화) 확률: 0.0213
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0159
# Class 3 (기타 괴롭힘 대화) 확률: 0.9441
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 488/500
# 일반대화 확률: 0.3054, 폭력대화 확률: 0.6946
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0790
# Class 1 (갈취 대화) 확률: 0.1900
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1006
# Class 3 (기타 괴롭힘 대화) 확률: 0.6305
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 489/500
# 일반대화 확률: 0.8751, 폭력대화 확률: 0.1249
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 490/500
# 일반대화 확률: 0.3320, 폭력대화 확률: 0.6680
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9709
# Class 1 (갈취 대화) 확률: 0.0083
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0130
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 491/500
# 일반대화 확률: 0.3197, 폭력대화 확률: 0.6803
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0633
# Class 1 (갈취 대화) 확률: 0.0207
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.9016
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 492/500
# 일반대화 확률: 0.4933, 폭력대화 확률: 0.5067
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 493/500
# 일반대화 확률: 0.1741, 폭력대화 확률: 0.8259
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0074
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0105
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 494/500
# 일반대화 확률: 0.4456, 폭력대화 확률: 0.5544
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 495/500
# 일반대화 확률: 0.1124, 폭력대화 확률: 0.8876
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0097
# Class 1 (갈취 대화) 확률: 0.9637
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0106
# Class 3 (기타 괴롭힘 대화) 확률: 0.0160
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 496/500
# 일반대화 확률: 0.4588, 폭력대화 확률: 0.5412
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 497/500
# 일반대화 확률: 0.4893, 폭력대화 확률: 0.5107
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 498/500
# 일반대화 확률: 0.1797, 폭력대화 확률: 0.8203
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0094
# Class 1 (갈취 대화) 확률: 0.9616
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0191
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 499/500
# 일반대화 확률: 0.2136, 폭력대화 확률: 0.7864
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9655
# Class 1 (갈취 대화) 확률: 0.0108
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0079
# Class 3 (기타 괴롭힘 대화) 확률: 0.0158
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 500/500
# 일반대화 확률: 0.5288, 폭력대화 확률: 0.4712
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Prediction distribution:
# prediction_label
# 기타 괴롭힘 대화      138
# 일반대화           137
# 갈취 대화           86
# 협박 대화           79
# 직장 내 괴롭힘 대화     60
# Name: count, dtype: int64
#
# [INFO] 예측 결과 저장 완료: /content/test_predictions_combined.csv

# %% [markdown]
# - 이진 분류 결과 출력

# %%
def predict_binary_only(text, binary_threshold=0.5):
    """이진 분류(일반/폭력)만 수행하는 함수"""
    # 이진 분류용 입력 처리
    inputs_bert = bert_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    input_ids_bert = inputs_bert["input_ids"].to(device)
    attention_mask_bert = inputs_bert["attention_mask"].to(device)

    with torch.no_grad():
        # SharedBERT로 특성 추출
        cls_output = shared_bert(input_ids_bert, attention_mask_bert)
        # 이진 분류
        binary_logits = binary_head(cls_output)
        binary_probs = F.softmax(binary_logits, dim=1)

        # 확률값 추출
        normal_prob = binary_probs[0][0].item()  # 일반대화 확률
        violent_prob = binary_probs[0][1].item()  # 폭력대화 확률

        # 결과 출력
        print(f"일반대화 확률: {normal_prob:.4f}, 폭력대화 확률: {violent_prob:.4f}")

        # 임계값 기반 분류
        binary_pred = 1 if violent_prob > binary_threshold else 0
        binary_label = '폭력대화' if binary_pred == 1 else '일반대화'

        print(f"Binary prediction: {binary_pred} ({binary_label})")

        return binary_pred, binary_label, normal_prob, violent_prob

# 테스트셋에 대해 이진 분류만 수행
print("\n[INFO] 테스트셋에 대한 이진 분류만 수행...")
test_df = pd.read_csv("/content/sample_data/test.csv")
print(f"테스트셋 크기: {len(test_df)}")

# 결과를 저장할 새 컬럼 추가
test_df["binary_pred"] = None
test_df["binary_label"] = None
test_df["normal_prob"] = None
test_df["violent_prob"] = None

# 각 샘플에 대해 이진 분류 수행
for i, text in enumerate(test_df["text"].tolist()):
    print(f"\n샘플 {i+1}/{len(test_df)} 예측 중...")
    binary_pred, binary_label, normal_prob, violent_prob = predict_binary_only(text, binary_threshold=0.6)

    # 결과 저장
    test_df.at[i, "binary_pred"] = binary_pred
    test_df.at[i, "binary_label"] = binary_label
    test_df.at[i, "normal_prob"] = normal_prob
    test_df.at[i, "violent_prob"] = violent_prob

# 이진 분류 예측 분포 확인
binary_counts = test_df["binary_label"].value_counts()
print("\n이진 분류 예측 분포:")
print(binary_counts)

# 실제 레이블이 있는 경우, 이진 분류 평가지표 계산
if "class" in test_df.columns:
    # 원래 레이블을 이진 레이블로 변환 (일반대화=0, 나머지=1)
    test_df["true_binary"] = test_df["class"].apply(lambda x: 0 if x == '일반대화' else 1)

    true_binary = test_df["true_binary"].tolist()
    pred_binary = test_df["binary_pred"].tolist()

    # 이진 분류 성능 평가
    binary_accuracy = accuracy_score(true_binary, pred_binary)
    binary_f1 = f1_score(true_binary, pred_binary, average='weighted')

    print("\n[INFO] 이진 분류 평가 결과:")
    print(f"정확도: {binary_accuracy:.4f}")
    print(f"F1 점수: {binary_f1:.4f}")
    print("\n혼동 행렬:")
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(true_binary, pred_binary)
    print(cm)

    # 상세한 분류 보고서
    print("\n분류 보고서:")
    print(classification_report(true_binary, pred_binary, target_names=['일반대화', '폭력대화']))

# 결과 저장
test_df.to_csv("/content/binary_classification_results.csv", index=False)
print("\n[INFO] 이진 분류 결과 저장 완료: /content/binary_classification_results.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-2bf93e6d2bfa> in <cell line: 0>()
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#       4 from torch.utils.data import Dataset, DataLoader
#       5 from transformers import AutoModel, AutoTokenizer, BertModel, BertTokenizer
#
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py in <module>
#    2591
#    2592
# -> 2593 from torch import (
#    2594     export as export,
#    2595     func as func,
#
# /usr/local/lib/python3.11/dist-packages/torch/func/__init__.py in <module>
# ----> 1 from torch._functorch.eager_transforms import (
#       2     vjp,
#       3     jvp,
#       4     jacrev,
#       5     jacfwd,
#
# /usr/local/lib/python3.11/dist-packages/torch/_functorch/eager_transforms.py in <module>
#      31 from torch._functorch.utils import argnums_t, exposed_in
#      32 from torch._subclasses.functional_tensor import FunctionalTensor
# ---> 33 from torch.fx.experimental import const_fold
#      34 from torch.fx.experimental.proxy_tensor import make_fx
#      35 from torch.utils import _pytree as pytree
#
# /usr/local/lib/python3.11/dist-packages/torch/fx/experimental/const_fold.py in <module>
#      15
#      16
# ---> 17 class FoldedGraphModule(torch.fx.GraphModule):
#      18     """
#      19     FoldedGraphModule is a GraphModule which also contains another
#
# AttributeError: partially initialized module 'torch' has no attribute 'fx' (most likely due to a circular import)

# %% [markdown]
# - 파일 병합

# %%
import pandas as pd

# 파일 경로 정의
predictions_path = "/content/test_predictions_combined.csv"
submission_path = "/content/submission.csv"

try:
    # 1. 파일 로드
    predictions_df = pd.read_csv(predictions_path)
    submission_df = pd.read_csv(submission_path)

    print(f"예측 결과 파일 로드 완료: {len(predictions_df)}개 행")
    print(f"제출 파일 로드 완료: {len(submission_df)}개 행")

    # 2. prediction 컬럼 확인
    if 'prediction' not in predictions_df.columns:
        print(f"'prediction' 컬럼이 없습니다. 사용 가능한 컬럼: {predictions_df.columns.tolist()}")
        raise ValueError("prediction 컬럼이 없습니다.")

    # 3. class 컬럼 업데이트
    submission_df['class'] = predictions_df['prediction'].values[:len(submission_df)]

    # 4. 업데이트된 파일 저장
    submission_df.to_csv(submission_path, index=False)
    print(f"\n{submission_path} 파일이 업데이트되었습니다.")

    # 5. 업데이트된 파일 확인
    print("\n업데이트된 submission.csv 파일의 처음 5개 행:")
    print(submission_df.head(5))

    # 6. 클래스 분포 확인
    if pd.api.types.is_numeric_dtype(submission_df['class']):
        class_counts = submission_df['class'].value_counts().sort_index()
        print("\n클래스 분포:")

        # 클래스 이름 매핑
        label_map = {
            0: '협박 대화',
            1: '갈취 대화',
            2: '직장 내 괴롭힘 대화',
            3: '기타 괴롭힘 대화',
            4: '일반대화'
        }

        for class_num, count in class_counts.items():
            class_name = label_map.get(class_num, f"알 수 없음({class_num})")
            print(f"클래스 {class_num} ({class_name}): {count}개")

except FileNotFoundError as e:
    print(f"파일을 찾을 수 없습니다: {e}")
    print("파일 경로가 올바른지 확인하세요.")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 예측 결과 파일 로드 완료: 500개 행
# 제출 파일 로드 완료: 500개 행
#
# /content/submission.csv 파일이 업데이트되었습니다.
#
# 업데이트된 submission.csv 파일의 처음 5개 행:
#   file_name  class
# 0     t_000      2
# 1     t_001      2
# 2     t_002      2
# 3     t_003      3
# 4     t_004      3
#
# 클래스 분포:
# 클래스 0 (협박 대화): 72개
# 클래스 1 (갈취 대화): 92개
# 클래스 2 (직장 내 괴롭힘 대화): 109개
# 클래스 3 (기타 괴롭힘 대화): 122개
# 클래스 4 (일반대화): 105개

# %% [markdown]
# # 3. 룰 기반 필터 추가

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer, BertModel, BertTokenizer
from torch.optim import AdamW
import pandas as pd
import numpy as np
import re  # Added for regex pattern matching
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import WeightedRandomSampler

# Rule-based filter function
def rule_based_filter(text):
    # 이름+씨 패턴이 있고, 공격적인 말이 같이 있으면 괴롭힘
    if re.search(r"[가-힣]{2,4}씨", text):
        return 2  # '직장 내 괴롭힘 대화' 클래스에 해당하는 인덱스
    return None  # 없으면 None 반환해서 모델 기반 분류 진행

# KoELECTRA tokenizer 로드 - 다중 분류기용
electra_tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-discriminator")
# KcBERT tokenizer 로드 - 이진 분류기용
bert_tokenizer = BertTokenizer.from_pretrained("beomi/kcbert-base")

# 클래스명-정수 매핑
label_map_str2int = {
    '협박 대화': 0,
    '갈취 대화': 1,
    '직장 내 괴롭힘 대화': 2,
    '기타 괴롭힘 대화': 3,
    '일반대화': 4
}
label_map_int2str = {v: k for k, v in label_map_str2int.items()}

# 이진 분류용 SharedBERT 모델
class SharedBERT(nn.Module):
    def __init__(self, model_name="beomi/kcbert-base"):
        super().__init__()
        self.bert = BertModel.from_pretrained(model_name)
        for p in self.bert.parameters():
            p.requires_grad = False

    def forward(self, input_ids, attention_mask):
        return self.bert(input_ids=input_ids, attention_mask=attention_mask).pooler_output

# 이진 분류기 정의
class BinaryClassifier(nn.Module):
    def __init__(self, hidden_size=768):
        super().__init__()
        self.classifier = nn.Linear(hidden_size, 2)

    def forward(self, cls_output):
        return self.classifier(cls_output)

# 이진 분류 데이터셋
class BinaryClassificationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.texts = dataframe['conversation'].tolist()
        self.labels = [label_map_str2int[label] for label in dataframe['class'].tolist()]
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.binary_labels = [0 if label == 4 else 1 for label in self.labels]

        # 디버깅을 위한 레이블 분포 출력
        unique, counts = np.unique(self.binary_labels, return_counts=True)
        print(f"Binary label distribution: {dict(zip(unique, counts))}")

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )
        item = {key: val.squeeze(0) for key, val in encoding.items()}
        item['label'] = torch.tensor(self.binary_labels[idx], dtype=torch.long)
        item['original_label'] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

# 다중 분류용 데이터셋 클래스 정의
class MultiClassificationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.label_map = label_map_str2int

        # 폭력 대화만 사용 (일반대화 제외)
        self.data = self.data[self.data['class'] != '일반대화'].copy()

        # 다중 레이블 설정
        self.multi_labels = [self.label_map[row['class']] for _, row in self.data.iterrows()]
        unique, counts = np.unique(self.multi_labels, return_counts=True)
        print(f"Multi-class label distribution: {dict(zip(unique, counts))}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = self.data.iloc[index]['conversation']
        label_str = self.data.iloc[index]['class']
        label = self.label_map[label_str]  # 0-3 레이블

        inputs = self.tokenizer(text,
                               truncation=True,
                               padding='max_length',
                               max_length=self.max_len,
                               return_tensors="pt")

        input_ids = inputs['input_ids'].squeeze()
        attention_mask = inputs['attention_mask'].squeeze()

        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'label': torch.tensor(label, dtype=torch.long)
        }

    # 샘플링 가중치 계산용 함수
    def get_labels(self):
        return self.multi_labels

# KoELECTRA + LSTM 다중 분류 모델 (4개 클래스)
class KoELECTRA_LSTM_MultiClassifier(nn.Module):
    def __init__(self, bert_model_name='monologg/koelectra-base-discriminator', hidden_size=128, lstm_layers=1, dropout=0.3, freeze_bert=False):
        super().__init__()
        self.bert = AutoModel.from_pretrained(bert_model_name)
        self.freeze_bert = freeze_bert
        self.lstm = nn.LSTM(input_size=self.bert.config.hidden_size, hidden_size=hidden_size,
                            num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden_size * 2, 4)  # 4개 클래스 (0-3)

    def forward(self, input_ids, attention_mask):
        if self.freeze_bert:
            with torch.no_grad():
                bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        else:
            bert_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        sequence_output = bert_output.last_hidden_state
        lstm_output, _ = self.lstm(sequence_output)
        pooled_output = lstm_output[:, -1, :]
        out = self.dropout(pooled_output)
        logits = self.classifier(out)
        return logits

# 이진 분류기 학습 함수
def train_binary_model(shared_bert, binary_head, train_loader, optimizer, device, epochs=10):
    for epoch in range(epochs):
        shared_bert.eval()  # 사전 학습된 BERT는 고정
        binary_head.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            with torch.no_grad():
                cls_output = shared_bert(input_ids, attention_mask)
            logits = binary_head(cls_output)
            loss = F.cross_entropy(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(logits, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        print(f"[Binary Epoch {epoch+1}/{epochs}] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}")

    return binary_head

# 다중 분류기 학습 함수
def train_with_scheduler(model, train_loader, val_loader, optimizer, scheduler, criterion, device, epochs=5, patience=2):
    best_val_f1 = 0.0
    patience_counter = 0

    for epoch in range(epochs):
        # 학습
        model.train()
        total_loss = 0
        train_preds = []
        train_true = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()

            # 그래디언트 클리핑 추가
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()
            scheduler.step()  # 스케줄러 업데이트

            total_loss += loss.item()

            # 학습 중 정확도 계산용
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_true.extend(labels.cpu().numpy())

        avg_train_loss = total_loss / len(train_loader)
        train_accuracy = accuracy_score(train_true, train_preds)
        train_f1 = f1_score(train_true, train_preds, average='weighted')

        # 검증
        model.eval()
        val_loss = 0
        val_preds = []
        val_true = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_true.extend(labels.cpu().numpy())

        # 클래스별 성능 평가
        val_report = classification_report(val_true, val_preds, output_dict=True)
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = accuracy_score(val_true, val_preds)
        val_f1 = f1_score(val_true, val_preds, average='weighted')

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}")

        # 각 클래스별 성능 출력
        for cls in sorted(set(val_true)):
            cls_str = str(cls)
            if cls_str in val_report:
                print(f"Class {cls}: F1={val_report[cls_str]['f1-score']:.4f}, Recall={val_report[cls_str]['recall']:.4f}")

        # 조기 종료 체크 (F1 스코어 기반)
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            patience_counter = 0
            # 최적 모델 저장
            torch.save(model.state_dict(), 'best_multi_model.pt')
            print("새로운 최적 모델 저장!")
        else:
            patience_counter += 1
            print(f"성능 개선 없음: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("조기 종료!")
                break

    # 최적 모델 로드
    model.load_state_dict(torch.load('best_multi_model.pt'))
    return model

# 학습 준비
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 데이터 로드
data = pd.read_csv("/content/sample_data/merged_dataset.csv")
print(f"Total data size: {len(data)}")

# 클래스 분포 확인
class_counts = data['class'].value_counts()
print("Class distribution:")
print(class_counts)

# 이진 분류 및 다중 분류를 위한 데이터 분할
train_data, val_data = train_test_split(data, test_size=0.2, stratify=data['class'], random_state=42)
print(f"Training set: {len(train_data)}, validation set: {len(val_data)}")

# 이진 분류 모델 준비
shared_bert = SharedBERT(model_name="beomi/kcbert-base").to(device)
binary_head = BinaryClassifier().to(device)

# 이진 분류 데이터셋 및 데이터로더 생성
train_dataset_binary = BinaryClassificationDataset(train_data, bert_tokenizer, max_length=128)
val_dataset_binary = BinaryClassificationDataset(val_data, bert_tokenizer, max_length=128)

# 이진 분류 데이터로더
train_loader_binary = DataLoader(train_dataset_binary, batch_size=32, shuffle=True)
val_loader_binary = DataLoader(val_dataset_binary, batch_size=32, shuffle=False)

# 이진 분류 모델 학습
optimizer_binary = torch.optim.Adam(binary_head.parameters(), lr=2e-5)

print("\n[INFO] Training Binary Classifier...")
binary_head = train_binary_model(shared_bert, binary_head, train_loader_binary, optimizer_binary, device, epochs=10)

# 이진 분류 모델 저장
torch.save(binary_head.state_dict(), "binary_classifier.pt")
print("Binary classifier model saved as 'binary_classifier.pt'")

# 다중 분류용 데이터셋 준비 - 일반대화 제외
train_dataset_multi = MultiClassificationDataset(train_data, electra_tokenizer, max_len=128)
val_dataset_multi = MultiClassificationDataset(val_data, electra_tokenizer, max_len=128)

# 불균형 데이터 처리를 위한 가중치 샘플링 설정 (다중 분류용)
multi_labels = train_dataset_multi.get_labels()
unique_multi_labels = np.unique(multi_labels)
multi_class_weights = compute_class_weight(class_weight='balanced',
                                         classes=unique_multi_labels,
                                         y=multi_labels)
# 클래스 인덱스를 dictionary로 변환
multi_weight_dict = {cls: weight for cls, weight in zip(unique_multi_labels, multi_class_weights)}
multi_samples_weight = [multi_weight_dict[lbl] for lbl in multi_labels]
multi_sampler = WeightedRandomSampler(weights=multi_samples_weight,
                                    num_samples=len(multi_samples_weight),
                                    replacement=True)

# 다중 분류용 데이터로더 생성
train_loader_multi = DataLoader(train_dataset_multi, batch_size=16, sampler=multi_sampler)
val_loader_multi = DataLoader(val_dataset_multi, batch_size=16, shuffle=False)

# 다중 분류 모델 생성
model_multi = KoELECTRA_LSTM_MultiClassifier(freeze_bert=False).to(device)

# 손실 함수 정의 (클래스 가중치 적용) - 다중 분류용
multi_loss_weights = torch.tensor(multi_class_weights, dtype=torch.float).to(device)
criterion_multi = nn.CrossEntropyLoss(weight=multi_loss_weights)

# 옵티마이저 설정 - 다중 분류용
optimizer_multi = AdamW(model_multi.parameters(), lr=2e-5)

# 학습률 스케줄러 추가
from transformers import get_linear_schedule_with_warmup

# 총 훈련 스텝 계산 - 다중 분류용
num_epochs = 5
total_steps_multi = len(train_loader_multi) * num_epochs
warmup_steps_multi = int(total_steps_multi * 0.1)  # 10% 웜업
scheduler_multi = get_linear_schedule_with_warmup(
    optimizer_multi, num_warmup_steps=warmup_steps_multi, num_training_steps=total_steps_multi
)

# 다중 분류 모델 학습
print("\n[INFO] Training Multi Classifier...")
model_multi = train_with_scheduler(model_multi, train_loader_multi, val_loader_multi,
                  optimizer_multi, scheduler_multi, criterion_multi, device, epochs=num_epochs, patience=2)

# 추론 함수 - 룰 기반 필터링 추가
def predict(text, binary_threshold=0.5):
    # 룰 기반 필터 먼저 적용
    rule_result = rule_based_filter(text)
    if rule_result is not None:
        print(f"Rule-based filter triggered: {rule_result} ({label_map_int2str[rule_result]})")
        return rule_result

    # 이진 분류 (일반/폭력)
    inputs_bert = bert_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    input_ids_bert = inputs_bert["input_ids"].to(device)
    attention_mask_bert = inputs_bert["attention_mask"].to(device)

    with torch.no_grad():
        # SharedBERT로 특성 추출
        cls_output = shared_bert(input_ids_bert, attention_mask_bert)
        # 이진 분류
        binary_logits = binary_head(cls_output)
        binary_probs = F.softmax(binary_logits, dim=1)

        # 확률값 추출
        normal_prob = binary_probs[0][0].item()  # 일반대화 확률
        violent_prob = binary_probs[0][1].item()  # 폭력대화 확률

        print(f"일반대화 확률: {normal_prob:.4f}, 폭력대화 확률: {violent_prob:.4f}")

        # 임계값 기반 분류
        binary_pred = 1 if violent_prob > binary_threshold else 0

        print(f"Binary prediction: {binary_pred} ({'폭력대화' if binary_pred == 1 else '일반대화'})")

        # 일반 대화로 분류된 경우
        if binary_pred == 0:
            return 4  # 일반대화

        # 폭력 대화로 분류된 경우, 세부 유형 분류
        inputs_electra = electra_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
        input_ids_electra = inputs_electra["input_ids"].to(device)
        attention_mask_electra = inputs_electra["attention_mask"].to(device)

        multi_logits = model_multi(input_ids=input_ids_electra, attention_mask=attention_mask_electra)
        multi_probs = F.softmax(multi_logits, dim=1)
        multi_pred = torch.argmax(multi_logits, dim=1).item()

        # 확률값 출력
        for i, prob in enumerate(multi_probs[0].cpu().numpy()):
            print(f"Class {i} ({label_map_int2str[i]}) 확률: {prob:.4f}")

        print(f"Multi prediction: {multi_pred} ({label_map_int2str[multi_pred]})")
        return multi_pred

# 테스트셋 평가
print("\n[INFO] Loading test set...")
test_df = pd.read_csv("/content/sample_data/test.csv")
print(f"Test set size: {len(test_df)}")

predicted_labels = []

# 원래 레이블 매핑과 동일한 매핑 사용
label_map = label_map_int2str

# text 컬럼을 기준으로 예측 수행
test_texts = test_df["text"].tolist()
for i, text in enumerate(test_texts):
    print(f"\nPredicting sample {i+1}/{len(test_texts)}")
    pred = predict(text, binary_threshold=0.6)  # 임계값 적용
    predicted_labels.append(pred)
    print(f"Final prediction: {pred} ({label_map[pred]})")

test_df["prediction"] = predicted_labels
test_df["prediction_label"] = test_df["prediction"].map(label_map)

# 클래스별 예측 분포 확인
pred_counts = test_df["prediction_label"].value_counts()
print("\nPrediction distribution:")
print(pred_counts)

# 실제 레이블이 있는 경우 평가 지표 계산
if "class" in test_df.columns:
    test_df["true_label_id"] = test_df["class"].map(label_map_str2int)
    true_labels = test_df["true_label_id"].tolist()

    print("\n[INFO] Classification Report:")
    print(classification_report(true_labels, predicted_labels, target_names=list(label_map_str2int.keys())))

    accuracy = accuracy_score(true_labels, predicted_labels)
    f1 = f1_score(true_labels, predicted_labels, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1 Score (weighted): {f1:.4f}")

# 결과 저장
test_df.to_csv("/content/test_predictions_combined.csv", index=False)
print("\n[INFO] 예측 결과 저장 완료: /content/test_predictions_combined.csv")
# Out:
# Using device: cuda
# Total data size: 7637
# Class distribution:
# class
# 일반대화           3687
# 기타 괴롭힘 대화      1094
# 갈취 대화           981
# 직장 내 괴롭힘 대화     979
# 협박 대화           896
# Name: count, dtype: int64
# Training set: 6109, validation set: 1528
# Binary label distribution: {np.int64(0): np.int64(2949), np.int64(1): np.int64(3160)}
# Binary label distribution: {np.int64(0): np.int64(738), np.int64(1): np.int64(790)}
#
# [INFO] Training Binary Classifier...
# [Binary Epoch 1/10] Loss: 0.7073, Accuracy: 0.5562, F1: 0.5056
# [Binary Epoch 2/10] Loss: 0.6389, Accuracy: 0.7464, F1: 0.7464
# [Binary Epoch 3/10] Loss: 0.5930, Accuracy: 0.7959, F1: 0.7958
# [Binary Epoch 4/10] Loss: 0.5550, Accuracy: 0.8253, F1: 0.8253
# [Binary Epoch 5/10] Loss: 0.5214, Accuracy: 0.8520, F1: 0.8520
# [Binary Epoch 6/10] Loss: 0.4914, Accuracy: 0.8798, F1: 0.8799
# [Binary Epoch 7/10] Loss: 0.4639, Accuracy: 0.9057, F1: 0.9057
# [Binary Epoch 8/10] Loss: 0.4386, Accuracy: 0.9204, F1: 0.9205
# [Binary Epoch 9/10] Loss: 0.4155, Accuracy: 0.9311, F1: 0.9311
# [Binary Epoch 10/10] Loss: 0.3942, Accuracy: 0.9417, F1: 0.9417
# Binary classifier model saved as 'binary_classifier.pt'
# Multi-class label distribution: {np.int64(0): np.int64(717), np.int64(1): np.int64(785), np.int64(2): np.int64(783), np.int64(3): np.int64(875)}
# Multi-class label distribution: {np.int64(0): np.int64(179), np.int64(1): np.int64(196), np.int64(2): np.int64(196), np.int64(3): np.int64(219)}
#
# [INFO] Training Multi Classifier...
#
# Epoch 1/5
# Train Loss: 1.2069, Train Accuracy: 0.4668, Train F1: 0.4642
# Val Loss: 0.7765, Val Accuracy: 0.7544, Val F1: 0.7559
# Class 0: F1=0.7361, Recall=0.8883
# Class 1: F1=0.7757, Recall=0.7500
# Class 2: F1=0.8357, Recall=0.7653
# Class 3: F1=0.6829, Recall=0.6393
# 새로운 최적 모델 저장!
#
# Epoch 2/5
# Train Loss: 0.5417, Train Accuracy: 0.8440, Train F1: 0.8426
# Val Loss: 0.4976, Val Accuracy: 0.8519, Val F1: 0.8503
# Class 0: F1=0.8013, Recall=0.7095
# Class 1: F1=0.8640, Recall=0.8265
# Class 2: F1=0.9091, Recall=0.9694
# Class 3: F1=0.8255, Recall=0.8858
# 새로운 최적 모델 저장!
#
# Epoch 3/5
# Train Loss: 0.3005, Train Accuracy: 0.9241, Train F1: 0.9240
# Val Loss: 0.4516, Val Accuracy: 0.8772, Val F1: 0.8761
# Class 0: F1=0.8431, Recall=0.7654
# Class 1: F1=0.8753, Recall=0.8776
# Class 2: F1=0.9153, Recall=0.9643
# Class 3: F1=0.8686, Recall=0.8904
# 새로운 최적 모델 저장!
#
# Epoch 4/5
# Train Loss: 0.2200, Train Accuracy: 0.9427, Train F1: 0.9427
# Val Loss: 0.4535, Val Accuracy: 0.8772, Val F1: 0.8764
# Class 0: F1=0.8387, Recall=0.7989
# Class 1: F1=0.8773, Recall=0.8571
# Class 2: F1=0.9216, Recall=0.9592
# Class 3: F1=0.8661, Recall=0.8858
# 새로운 최적 모델 저장!
#
# Epoch 5/5
# Train Loss: 0.1820, Train Accuracy: 0.9566, Train F1: 0.9566
# Val Loss: 0.4634, Val Accuracy: 0.8797, Val F1: 0.8790
# Class 0: F1=0.8443, Recall=0.7877
# Class 1: F1=0.8698, Recall=0.8520
# Class 2: F1=0.9250, Recall=0.9439
# Class 3: F1=0.8745, Recall=0.9224
# 새로운 최적 모델 저장!
#
# [INFO] Loading test set...
# Test set size: 500
#
# Predicting sample 1/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 2/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 3/500
# 일반대화 확률: 0.0822, 폭력대화 확률: 0.9178
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0120
# Class 1 (갈취 대화) 확률: 0.0114
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9563
# Class 3 (기타 괴롭힘 대화) 확률: 0.0202
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 4/500
# 일반대화 확률: 0.1550, 폭력대화 확률: 0.8450
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0298
# Class 1 (갈취 대화) 확률: 0.0642
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0249
# Class 3 (기타 괴롭힘 대화) 확률: 0.8811
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 5/500
# 일반대화 확률: 0.2310, 폭력대화 확률: 0.7690
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0228
# Class 1 (갈취 대화) 확률: 0.0356
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0176
# Class 3 (기타 괴롭힘 대화) 확률: 0.9239
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 6/500
# 일반대화 확률: 0.2021, 폭력대화 확률: 0.7979
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9718
# Class 1 (갈취 대화) 확률: 0.0097
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0103
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 7/500
# 일반대화 확률: 0.3949, 폭력대화 확률: 0.6051
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9709
# Class 1 (갈취 대화) 확률: 0.0104
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0071
# Class 3 (기타 괴롭힘 대화) 확률: 0.0116
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 8/500
# 일반대화 확률: 0.1777, 폭력대화 확률: 0.8223
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0294
# Class 1 (갈취 대화) 확률: 0.7997
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0096
# Class 3 (기타 괴롭힘 대화) 확률: 0.1613
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 9/500
# 일반대화 확률: 0.5496, 폭력대화 확률: 0.4504
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 10/500
# 일반대화 확률: 0.2056, 폭력대화 확률: 0.7944
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0192
# Class 1 (갈취 대화) 확률: 0.9522
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.0190
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 11/500
# 일반대화 확률: 0.3432, 폭력대화 확률: 0.6568
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9752
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0088
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 12/500
# 일반대화 확률: 0.3295, 폭력대화 확률: 0.6705
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0280
# Class 1 (갈취 대화) 확률: 0.0396
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0686
# Class 3 (기타 괴롭힘 대화) 확률: 0.8638
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 13/500
# 일반대화 확률: 0.5112, 폭력대화 확률: 0.4888
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 14/500
# 일반대화 확률: 0.3062, 폭력대화 확률: 0.6938
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0102
# Class 1 (갈취 대화) 확률: 0.0102
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9654
# Class 3 (기타 괴롭힘 대화) 확률: 0.0142
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 15/500
# 일반대화 확률: 0.3618, 폭력대화 확률: 0.6382
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0109
# Class 1 (갈취 대화) 확률: 0.0105
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9624
# Class 3 (기타 괴롭힘 대화) 확률: 0.0162
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 16/500
# 일반대화 확률: 0.3550, 폭력대화 확률: 0.6450
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9325
# Class 1 (갈취 대화) 확률: 0.0229
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0090
# Class 3 (기타 괴롭힘 대화) 확률: 0.0355
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 17/500
# 일반대화 확률: 0.4760, 폭력대화 확률: 0.5240
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 18/500
# 일반대화 확률: 0.3058, 폭력대화 확률: 0.6942
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0476
# Class 1 (갈취 대화) 확률: 0.0402
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0680
# Class 3 (기타 괴롭힘 대화) 확률: 0.8443
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 19/500
# 일반대화 확률: 0.3408, 폭력대화 확률: 0.6592
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9748
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0091
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 20/500
# 일반대화 확률: 0.5243, 폭력대화 확률: 0.4757
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 21/500
# 일반대화 확률: 0.3439, 폭력대화 확률: 0.6561
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9730
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0088
# Class 3 (기타 괴롭힘 대화) 확률: 0.0097
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 22/500
# 일반대화 확률: 0.1737, 폭력대화 확률: 0.8263
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0280
# Class 1 (갈취 대화) 확률: 0.0221
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0153
# Class 3 (기타 괴롭힘 대화) 확률: 0.9346
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 23/500
# 일반대화 확률: 0.3796, 폭력대화 확률: 0.6204
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0530
# Class 1 (갈취 대화) 확률: 0.0281
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0161
# Class 3 (기타 괴롭힘 대화) 확률: 0.9028
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 24/500
# 일반대화 확률: 0.2007, 폭력대화 확률: 0.7993
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0209
# Class 1 (갈취 대화) 확률: 0.9492
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0088
# Class 3 (기타 괴롭힘 대화) 확률: 0.0211
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 25/500
# 일반대화 확률: 0.3352, 폭력대화 확률: 0.6648
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0202
# Class 1 (갈취 대화) 확률: 0.9513
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0089
# Class 3 (기타 괴롭힘 대화) 확률: 0.0196
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 26/500
# 일반대화 확률: 0.2352, 폭력대화 확률: 0.7648
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0099
# Class 1 (갈취 대화) 확률: 0.0100
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9657
# Class 3 (기타 괴롭힘 대화) 확률: 0.0144
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 27/500
# 일반대화 확률: 0.1147, 폭력대화 확률: 0.8853
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0309
# Class 1 (갈취 대화) 확률: 0.0297
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0167
# Class 3 (기타 괴롭힘 대화) 확률: 0.9227
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 28/500
# 일반대화 확률: 0.2005, 폭력대화 확률: 0.7995
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0229
# Class 1 (갈취 대화) 확률: 0.0358
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0197
# Class 3 (기타 괴롭힘 대화) 확률: 0.9217
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 29/500
# 일반대화 확률: 0.3225, 폭력대화 확률: 0.6775
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0110
# Class 1 (갈취 대화) 확률: 0.0102
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9624
# Class 3 (기타 괴롭힘 대화) 확률: 0.0164
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 30/500
# 일반대화 확률: 0.3336, 폭력대화 확률: 0.6664
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1992
# Class 1 (갈취 대화) 확률: 0.6516
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0174
# Class 3 (기타 괴롭힘 대화) 확률: 0.1318
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 31/500
# 일반대화 확률: 0.4736, 폭력대화 확률: 0.5264
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 32/500
# 일반대화 확률: 0.3575, 폭력대화 확률: 0.6425
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9735
# Class 1 (갈취 대화) 확률: 0.0096
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0075
# Class 3 (기타 괴롭힘 대화) 확률: 0.0094
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 33/500
# 일반대화 확률: 0.1415, 폭력대화 확률: 0.8585
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0271
# Class 1 (갈취 대화) 확률: 0.0358
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0234
# Class 3 (기타 괴롭힘 대화) 확률: 0.9138
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 34/500
# 일반대화 확률: 0.2878, 폭력대화 확률: 0.7122
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0367
# Class 1 (갈취 대화) 확률: 0.7975
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0114
# Class 3 (기타 괴롭힘 대화) 확률: 0.1544
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 35/500
# 일반대화 확률: 0.3698, 폭력대화 확률: 0.6302
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8571
# Class 1 (갈취 대화) 확률: 0.0286
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0129
# Class 3 (기타 괴롭힘 대화) 확률: 0.1015
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 36/500
# 일반대화 확률: 0.0777, 폭력대화 확률: 0.9223
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0191
# Class 1 (갈취 대화) 확률: 0.9263
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0091
# Class 3 (기타 괴롭힘 대화) 확률: 0.0455
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 37/500
# 일반대화 확률: 0.3960, 폭력대화 확률: 0.6040
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0501
# Class 1 (갈취 대화) 확률: 0.7604
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0100
# Class 3 (기타 괴롭힘 대화) 확률: 0.1795
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 38/500
# 일반대화 확률: 0.1481, 폭력대화 확률: 0.8519
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9260
# Class 1 (갈취 대화) 확률: 0.0450
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0195
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 39/500
# 일반대화 확률: 0.2900, 폭력대화 확률: 0.7100
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9726
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0089
# Class 3 (기타 괴롭힘 대화) 확률: 0.0099
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 40/500
# 일반대화 확률: 0.1723, 폭력대화 확률: 0.8277
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0218
# Class 1 (갈취 대화) 확률: 0.9480
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0076
# Class 3 (기타 괴롭힘 대화) 확률: 0.0226
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 41/500
# 일반대화 확률: 0.4292, 폭력대화 확률: 0.5708
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 42/500
# 일반대화 확률: 0.1124, 폭력대화 확률: 0.8876
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0179
# Class 1 (갈취 대화) 확률: 0.9429
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0313
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 43/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 44/500
# 일반대화 확률: 0.5511, 폭력대화 확률: 0.4489
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 45/500
# 일반대화 확률: 0.2403, 폭력대화 확률: 0.7597
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0270
# Class 1 (갈취 대화) 확률: 0.0355
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0236
# Class 3 (기타 괴롭힘 대화) 확률: 0.9139
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 46/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 47/500
# 일반대화 확률: 0.2325, 폭력대화 확률: 0.7675
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9685
# Class 1 (갈취 대화) 확률: 0.0103
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0071
# Class 3 (기타 괴롭힘 대화) 확률: 0.0141
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 48/500
# 일반대화 확률: 0.3883, 폭력대화 확률: 0.6117
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0433
# Class 1 (갈취 대화) 확률: 0.0262
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0148
# Class 3 (기타 괴롭힘 대화) 확률: 0.9157
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 49/500
# 일반대화 확률: 0.3110, 폭력대화 확률: 0.6890
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0432
# Class 1 (갈취 대화) 확률: 0.0296
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0179
# Class 3 (기타 괴롭힘 대화) 확률: 0.9094
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 50/500
# 일반대화 확률: 0.1995, 폭력대화 확률: 0.8005
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9749
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0088
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 51/500
# 일반대화 확률: 0.4704, 폭력대화 확률: 0.5296
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 52/500
# 일반대화 확률: 0.2988, 폭력대화 확률: 0.7012
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0240
# Class 1 (갈취 대화) 확률: 0.0270
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0149
# Class 3 (기타 괴롭힘 대화) 확률: 0.9341
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 53/500
# 일반대화 확률: 0.2151, 폭력대화 확률: 0.7849
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0276
# Class 1 (갈취 대화) 확률: 0.9403
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0099
# Class 3 (기타 괴롭힘 대화) 확률: 0.0222
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 54/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 55/500
# 일반대화 확률: 0.5172, 폭력대화 확률: 0.4828
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 56/500
# 일반대화 확률: 0.1857, 폭력대화 확률: 0.8143
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0767
# Class 1 (갈취 대화) 확률: 0.0562
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0174
# Class 3 (기타 괴롭힘 대화) 확률: 0.8497
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 57/500
# 일반대화 확률: 0.2091, 폭력대화 확률: 0.7909
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0307
# Class 1 (갈취 대화) 확률: 0.0316
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0138
# Class 3 (기타 괴롭힘 대화) 확률: 0.9239
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 58/500
# 일반대화 확률: 0.4384, 폭력대화 확률: 0.5616
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 59/500
# 일반대화 확률: 0.0824, 폭력대화 확률: 0.9176
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0309
# Class 1 (갈취 대화) 확률: 0.0235
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0181
# Class 3 (기타 괴롭힘 대화) 확률: 0.9275
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 60/500
# 일반대화 확률: 0.2914, 폭력대화 확률: 0.7086
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0354
# Class 1 (갈취 대화) 확률: 0.0325
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0270
# Class 3 (기타 괴롭힘 대화) 확률: 0.9051
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 61/500
# 일반대화 확률: 0.3717, 폭력대화 확률: 0.6283
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0206
# Class 1 (갈취 대화) 확률: 0.9474
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0107
# Class 3 (기타 괴롭힘 대화) 확률: 0.0212
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 62/500
# 일반대화 확률: 0.4467, 폭력대화 확률: 0.5533
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 63/500
# 일반대화 확률: 0.5356, 폭력대화 확률: 0.4644
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 64/500
# 일반대화 확률: 0.1622, 폭력대화 확률: 0.8378
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0297
# Class 1 (갈취 대화) 확률: 0.0321
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0471
# Class 3 (기타 괴롭힘 대화) 확률: 0.8911
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 65/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 66/500
# 일반대화 확률: 0.1981, 폭력대화 확률: 0.8019
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9742
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0075
# Class 3 (기타 괴롭힘 대화) 확률: 0.0097
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 67/500
# 일반대화 확률: 0.1821, 폭력대화 확률: 0.8179
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2796
# Class 1 (갈취 대화) 확률: 0.0495
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0191
# Class 3 (기타 괴롭힘 대화) 확률: 0.6518
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 68/500
# 일반대화 확률: 0.3079, 폭력대화 확률: 0.6921
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0449
# Class 1 (갈취 대화) 확률: 0.0512
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0192
# Class 3 (기타 괴롭힘 대화) 확률: 0.8847
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 69/500
# 일반대화 확률: 0.5246, 폭력대화 확률: 0.4754
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 70/500
# 일반대화 확률: 0.0869, 폭력대화 확률: 0.9131
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0372
# Class 1 (갈취 대화) 확률: 0.9227
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0321
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 71/500
# 일반대화 확률: 0.1745, 폭력대화 확률: 0.8255
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1091
# Class 1 (갈취 대화) 확률: 0.0442
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0374
# Class 3 (기타 괴롭힘 대화) 확률: 0.8093
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 72/500
# 일반대화 확률: 0.4592, 폭력대화 확률: 0.5408
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 73/500
# 일반대화 확률: 0.1637, 폭력대화 확률: 0.8363
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0271
# Class 1 (갈취 대화) 확률: 0.0250
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0179
# Class 3 (기타 괴롭힘 대화) 확률: 0.9300
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 74/500
# 일반대화 확률: 0.3859, 폭력대화 확률: 0.6141
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0111
# Class 1 (갈취 대화) 확률: 0.0108
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9631
# Class 3 (기타 괴롭힘 대화) 확률: 0.0150
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 75/500
# 일반대화 확률: 0.3249, 폭력대화 확률: 0.6751
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9746
# Class 1 (갈취 대화) 확률: 0.0083
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0075
# Class 3 (기타 괴롭힘 대화) 확률: 0.0096
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 76/500
# 일반대화 확률: 0.2980, 폭력대화 확률: 0.7020
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0103
# Class 1 (갈취 대화) 확률: 0.0100
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9647
# Class 3 (기타 괴롭힘 대화) 확률: 0.0150
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 77/500
# 일반대화 확률: 0.2887, 폭력대화 확률: 0.7113
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1522
# Class 1 (갈취 대화) 확률: 0.0545
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.4995
# Class 3 (기타 괴롭힘 대화) 확률: 0.2938
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 78/500
# 일반대화 확률: 0.4444, 폭력대화 확률: 0.5556
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 79/500
# 일반대화 확률: 0.5331, 폭력대화 확률: 0.4669
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 80/500
# 일반대화 확률: 0.3725, 폭력대화 확률: 0.6275
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2912
# Class 1 (갈취 대화) 확률: 0.0646
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0642
# Class 3 (기타 괴롭힘 대화) 확률: 0.5800
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 81/500
# 일반대화 확률: 0.1027, 폭력대화 확률: 0.8973
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0204
# Class 1 (갈취 대화) 확률: 0.9255
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0085
# Class 3 (기타 괴롭힘 대화) 확률: 0.0455
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 82/500
# 일반대화 확률: 0.3619, 폭력대화 확률: 0.6381
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9714
# Class 1 (갈취 대화) 확률: 0.0109
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0073
# Class 3 (기타 괴롭힘 대화) 확률: 0.0104
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 83/500
# 일반대화 확률: 0.5158, 폭력대화 확률: 0.4842
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 84/500
# 일반대화 확률: 0.2793, 폭력대화 확률: 0.7207
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9728
# Class 1 (갈취 대화) 확률: 0.0100
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0095
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 85/500
# 일반대화 확률: 0.2606, 폭력대화 확률: 0.7394
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0467
# Class 1 (갈취 대화) 확률: 0.0262
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0182
# Class 3 (기타 괴롭힘 대화) 확률: 0.9089
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 86/500
# 일반대화 확률: 0.5841, 폭력대화 확률: 0.4159
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 87/500
# 일반대화 확률: 0.3067, 폭력대화 확률: 0.6933
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.6545
# Class 1 (갈취 대화) 확률: 0.2855
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0150
# Class 3 (기타 괴롭힘 대화) 확률: 0.0449
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 88/500
# 일반대화 확률: 0.2060, 폭력대화 확률: 0.7940
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0433
# Class 1 (갈취 대화) 확률: 0.0324
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0234
# Class 3 (기타 괴롭힘 대화) 확률: 0.9009
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 89/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 90/500
# 일반대화 확률: 0.2924, 폭력대화 확률: 0.7076
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0099
# Class 1 (갈취 대화) 확률: 0.0103
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9650
# Class 3 (기타 괴롭힘 대화) 확률: 0.0148
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 91/500
# 일반대화 확률: 0.4489, 폭력대화 확률: 0.5511
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 92/500
# 일반대화 확률: 0.4551, 폭력대화 확률: 0.5449
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 93/500
# 일반대화 확률: 0.0689, 폭력대화 확률: 0.9311
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9747
# Class 1 (갈취 대화) 확률: 0.0084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0087
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 94/500
# 일반대화 확률: 0.1353, 폭력대화 확률: 0.8647
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0236
# Class 1 (갈취 대화) 확률: 0.0310
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0139
# Class 3 (기타 괴롭힘 대화) 확률: 0.9315
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 95/500
# 일반대화 확률: 0.2096, 폭력대화 확률: 0.7904
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0238
# Class 1 (갈취 대화) 확률: 0.0224
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0162
# Class 3 (기타 괴롭힘 대화) 확률: 0.9376
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 96/500
# 일반대화 확률: 0.1711, 폭력대화 확률: 0.8289
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0106
# Class 1 (갈취 대화) 확률: 0.0101
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9647
# Class 3 (기타 괴롭힘 대화) 확률: 0.0146
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 97/500
# 일반대화 확률: 0.3020, 폭력대화 확률: 0.6980
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0751
# Class 1 (갈취 대화) 확률: 0.7662
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0136
# Class 3 (기타 괴롭힘 대화) 확률: 0.1450
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 98/500
# 일반대화 확률: 0.3657, 폭력대화 확률: 0.6343
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0105
# Class 1 (갈취 대화) 확률: 0.0125
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9602
# Class 3 (기타 괴롭힘 대화) 확률: 0.0168
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 99/500
# 일반대화 확률: 0.1606, 폭력대화 확률: 0.8394
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.6804
# Class 1 (갈취 대화) 확률: 0.2658
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0164
# Class 3 (기타 괴롭힘 대화) 확률: 0.0374
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 100/500
# 일반대화 확률: 0.2395, 폭력대화 확률: 0.7605
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2622
# Class 1 (갈취 대화) 확률: 0.0573
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.4950
# Class 3 (기타 괴롭힘 대화) 확률: 0.1855
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 101/500
# 일반대화 확률: 0.1635, 폭력대화 확률: 0.8365
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0283
# Class 1 (갈취 대화) 확률: 0.9033
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.0572
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 102/500
# 일반대화 확률: 0.3182, 폭력대화 확률: 0.6818
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0210
# Class 1 (갈취 대화) 확률: 0.9484
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0088
# Class 3 (기타 괴롭힘 대화) 확률: 0.0217
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 103/500
# 일반대화 확률: 0.1844, 폭력대화 확률: 0.8156
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0289
# Class 1 (갈취 대화) 확률: 0.0352
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0207
# Class 3 (기타 괴롭힘 대화) 확률: 0.9152
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 104/500
# 일반대화 확률: 0.2883, 폭력대화 확률: 0.7117
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9739
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0094
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 105/500
# 일반대화 확률: 0.3208, 폭력대화 확률: 0.6792
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2577
# Class 1 (갈취 대화) 확률: 0.0744
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1438
# Class 3 (기타 괴롭힘 대화) 확률: 0.5241
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 106/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 107/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 108/500
# 일반대화 확률: 0.3294, 폭력대화 확률: 0.6706
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0496
# Class 1 (갈취 대화) 확률: 0.0357
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0142
# Class 3 (기타 괴롭힘 대화) 확률: 0.9005
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 109/500
# 일반대화 확률: 0.2980, 폭력대화 확률: 0.7020
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0287
# Class 1 (갈취 대화) 확률: 0.0637
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0366
# Class 3 (기타 괴롭힘 대화) 확률: 0.8710
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 110/500
# 일반대화 확률: 0.4689, 폭력대화 확률: 0.5311
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 111/500
# 일반대화 확률: 0.2473, 폭력대화 확률: 0.7527
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0716
# Class 1 (갈취 대화) 확률: 0.1116
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0158
# Class 3 (기타 괴롭힘 대화) 확률: 0.8010
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 112/500
# 일반대화 확률: 0.2909, 폭력대화 확률: 0.7091
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9748
# Class 1 (갈취 대화) 확률: 0.0078
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0079
# Class 3 (기타 괴롭힘 대화) 확률: 0.0095
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 113/500
# 일반대화 확률: 0.4021, 폭력대화 확률: 0.5979
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 114/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 115/500
# 일반대화 확률: 0.2835, 폭력대화 확률: 0.7165
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0278
# Class 1 (갈취 대화) 확률: 0.8547
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0097
# Class 3 (기타 괴롭힘 대화) 확률: 0.1079
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 116/500
# 일반대화 확률: 0.3867, 폭력대화 확률: 0.6133
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0253
# Class 1 (갈취 대화) 확률: 0.9458
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0207
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 117/500
# 일반대화 확률: 0.1325, 폭력대화 확률: 0.8675
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0264
# Class 1 (갈취 대화) 확률: 0.9010
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0164
# Class 3 (기타 괴롭힘 대화) 확률: 0.0562
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 118/500
# 일반대화 확률: 0.3223, 폭력대화 확률: 0.6777
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0108
# Class 1 (갈취 대화) 확률: 0.0110
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9626
# Class 3 (기타 괴롭힘 대화) 확률: 0.0156
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 119/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 120/500
# 일반대화 확률: 0.2880, 폭력대화 확률: 0.7120
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0228
# Class 1 (갈취 대화) 확률: 0.9490
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0201
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 121/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 122/500
# 일반대화 확률: 0.2181, 폭력대화 확률: 0.7819
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0349
# Class 1 (갈취 대화) 확률: 0.1328
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0227
# Class 3 (기타 괴롭힘 대화) 확률: 0.8096
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 123/500
# 일반대화 확률: 0.1340, 폭력대화 확률: 0.8660
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.1068
# Class 1 (갈취 대화) 확률: 0.7744
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0101
# Class 3 (기타 괴롭힘 대화) 확률: 0.1087
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 124/500
# 일반대화 확률: 0.3519, 폭력대화 확률: 0.6481
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0210
# Class 1 (갈취 대화) 확률: 0.9488
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0222
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 125/500
# 일반대화 확률: 0.5778, 폭력대화 확률: 0.4222
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 126/500
# 일반대화 확률: 0.3131, 폭력대화 확률: 0.6869
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0279
# Class 1 (갈취 대화) 확률: 0.9407
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0074
# Class 3 (기타 괴롭힘 대화) 확률: 0.0240
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 127/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 128/500
# 일반대화 확률: 0.6529, 폭력대화 확률: 0.3471
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 129/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 130/500
# 일반대화 확률: 0.1674, 폭력대화 확률: 0.8326
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0309
# Class 1 (갈취 대화) 확률: 0.0252
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0181
# Class 3 (기타 괴롭힘 대화) 확률: 0.9258
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 131/500
# 일반대화 확률: 0.1376, 폭력대화 확률: 0.8624
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0315
# Class 1 (갈취 대화) 확률: 0.0363
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0135
# Class 3 (기타 괴롭힘 대화) 확률: 0.9187
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 132/500
# 일반대화 확률: 0.3236, 폭력대화 확률: 0.6764
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0299
# Class 1 (갈취 대화) 확률: 0.0335
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0140
# Class 3 (기타 괴롭힘 대화) 확률: 0.9226
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 133/500
# 일반대화 확률: 0.3021, 폭력대화 확률: 0.6979
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0107
# Class 1 (갈취 대화) 확률: 0.0104
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9621
# Class 3 (기타 괴롭힘 대화) 확률: 0.0168
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 134/500
# 일반대화 확률: 0.2669, 폭력대화 확률: 0.7331
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0262
# Class 1 (갈취 대화) 확률: 0.0361
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.9233
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 135/500
# 일반대화 확률: 0.2753, 폭력대화 확률: 0.7247
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0772
# Class 1 (갈취 대화) 확률: 0.8374
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0085
# Class 3 (기타 괴롭힘 대화) 확률: 0.0769
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 136/500
# 일반대화 확률: 0.2799, 폭력대화 확률: 0.7201
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9750
# Class 1 (갈취 대화) 확률: 0.0080
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0079
# Class 3 (기타 괴롭힘 대화) 확률: 0.0091
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 137/500
# 일반대화 확률: 0.3781, 폭력대화 확률: 0.6219
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9688
# Class 1 (갈취 대화) 확률: 0.0114
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0068
# Class 3 (기타 괴롭힘 대화) 확률: 0.0130
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 138/500
# 일반대화 확률: 0.2675, 폭력대화 확률: 0.7325
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9733
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0086
# Class 3 (기타 괴롭힘 대화) 확률: 0.0094
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 139/500
# 일반대화 확률: 0.0852, 폭력대화 확률: 0.9148
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0227
# Class 1 (갈취 대화) 확률: 0.0320
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0161
# Class 3 (기타 괴롭힘 대화) 확률: 0.9293
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 140/500
# 일반대화 확률: 0.2589, 폭력대화 확률: 0.7411
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0427
# Class 1 (갈취 대화) 확률: 0.0335
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0485
# Class 3 (기타 괴롭힘 대화) 확률: 0.8752
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 141/500
# 일반대화 확률: 0.1546, 폭력대화 확률: 0.8454
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9125
# Class 1 (갈취 대화) 확률: 0.0163
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0118
# Class 3 (기타 괴롭힘 대화) 확률: 0.0594
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 142/500
# 일반대화 확률: 0.1158, 폭력대화 확률: 0.8842
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0371
# Class 1 (갈취 대화) 확률: 0.0310
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0241
# Class 3 (기타 괴롭힘 대화) 확률: 0.9077
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 143/500
# 일반대화 확률: 0.1112, 폭력대화 확률: 0.8888
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0231
# Class 1 (갈취 대화) 확률: 0.9459
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0095
# Class 3 (기타 괴롭힘 대화) 확률: 0.0215
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 144/500
# 일반대화 확률: 0.3421, 폭력대화 확률: 0.6579
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0270
# Class 1 (갈취 대화) 확률: 0.0198
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0171
# Class 3 (기타 괴롭힘 대화) 확률: 0.9361
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 145/500
# 일반대화 확률: 0.2853, 폭력대화 확률: 0.7147
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0442
# Class 1 (갈취 대화) 확률: 0.0176
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9003
# Class 3 (기타 괴롭힘 대화) 확률: 0.0378
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 146/500
# 일반대화 확률: 0.4903, 폭력대화 확률: 0.5097
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 147/500
# 일반대화 확률: 0.4123, 폭력대화 확률: 0.5877
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 148/500
# 일반대화 확률: 0.4247, 폭력대화 확률: 0.5753
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 149/500
# 일반대화 확률: 0.3220, 폭력대화 확률: 0.6780
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0374
# Class 1 (갈취 대화) 확률: 0.0259
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0171
# Class 3 (기타 괴롭힘 대화) 확률: 0.9195
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 150/500
# 일반대화 확률: 0.0894, 폭력대화 확률: 0.9106
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0204
# Class 1 (갈취 대화) 확률: 0.9468
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0076
# Class 3 (기타 괴롭힘 대화) 확률: 0.0253
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 151/500
# 일반대화 확률: 0.5006, 폭력대화 확률: 0.4994
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 152/500
# 일반대화 확률: 0.3405, 폭력대화 확률: 0.6595
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0829
# Class 1 (갈취 대화) 확률: 0.0301
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0160
# Class 3 (기타 괴롭힘 대화) 확률: 0.8710
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 153/500
# 일반대화 확률: 0.4561, 폭력대화 확률: 0.5439
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 154/500
# 일반대화 확률: 0.2777, 폭력대화 확률: 0.7223
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0226
# Class 1 (갈취 대화) 확률: 0.9300
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0124
# Class 3 (기타 괴롭힘 대화) 확률: 0.0349
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 155/500
# 일반대화 확률: 0.3214, 폭력대화 확률: 0.6786
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0401
# Class 1 (갈취 대화) 확률: 0.0407
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1116
# Class 3 (기타 괴롭힘 대화) 확률: 0.8075
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 156/500
# 일반대화 확률: 0.2315, 폭력대화 확률: 0.7685
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0317
# Class 1 (갈취 대화) 확률: 0.0523
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0316
# Class 3 (기타 괴롭힘 대화) 확률: 0.8844
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 157/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 158/500
# 일반대화 확률: 0.3310, 폭력대화 확률: 0.6690
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0105
# Class 1 (갈취 대화) 확률: 0.0105
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9644
# Class 3 (기타 괴롭힘 대화) 확률: 0.0146
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 159/500
# 일반대화 확률: 0.2931, 폭력대화 확률: 0.7069
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0281
# Class 1 (갈취 대화) 확률: 0.0249
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0180
# Class 3 (기타 괴롭힘 대화) 확률: 0.9290
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 160/500
# 일반대화 확률: 0.2615, 폭력대화 확률: 0.7385
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0397
# Class 1 (갈취 대화) 확률: 0.0271
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0174
# Class 3 (기타 괴롭힘 대화) 확률: 0.9158
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 161/500
# 일반대화 확률: 0.3317, 폭력대화 확률: 0.6683
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9747
# Class 1 (갈취 대화) 확률: 0.0083
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0090
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 162/500
# 일반대화 확률: 0.2947, 폭력대화 확률: 0.7053
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0228
# Class 1 (갈취 대화) 확률: 0.0293
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0144
# Class 3 (기타 괴롭힘 대화) 확률: 0.9335
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 163/500
# 일반대화 확률: 0.6910, 폭력대화 확률: 0.3090
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 164/500
# 일반대화 확률: 0.3488, 폭력대화 확률: 0.6512
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9750
# Class 1 (갈취 대화) 확률: 0.0079
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0082
# Class 3 (기타 괴롭힘 대화) 확률: 0.0088
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 165/500
# 일반대화 확률: 0.1114, 폭력대화 확률: 0.8886
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0350
# Class 1 (갈취 대화) 확률: 0.0228
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0216
# Class 3 (기타 괴롭힘 대화) 확률: 0.9205
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 166/500
# 일반대화 확률: 0.1826, 폭력대화 확률: 0.8174
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0256
# Class 1 (갈취 대화) 확률: 0.0315
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0153
# Class 3 (기타 괴롭힘 대화) 확률: 0.9276
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 167/500
# 일반대화 확률: 0.3251, 폭력대화 확률: 0.6749
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0115
# Class 1 (갈취 대화) 확률: 0.0112
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9620
# Class 3 (기타 괴롭힘 대화) 확률: 0.0153
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 168/500
# 일반대화 확률: 0.2150, 폭력대화 확률: 0.7850
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0231
# Class 1 (갈취 대화) 확률: 0.0460
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0378
# Class 3 (기타 괴롭힘 대화) 확률: 0.8931
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 169/500
# 일반대화 확률: 0.1269, 폭력대화 확률: 0.8731
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0287
# Class 1 (갈취 대화) 확률: 0.0233
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0180
# Class 3 (기타 괴롭힘 대화) 확률: 0.9301
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 170/500
# 일반대화 확률: 0.1464, 폭력대화 확률: 0.8536
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0215
# Class 1 (갈취 대화) 확률: 0.9065
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0118
# Class 3 (기타 괴롭힘 대화) 확률: 0.0602
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 171/500
# 일반대화 확률: 0.4411, 폭력대화 확률: 0.5589
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 172/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 173/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 174/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 175/500
# 일반대화 확률: 0.4912, 폭력대화 확률: 0.5088
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 176/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 177/500
# 일반대화 확률: 0.4853, 폭력대화 확률: 0.5147
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 178/500
# 일반대화 확률: 0.4852, 폭력대화 확률: 0.5148
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 179/500
# 일반대화 확률: 0.3809, 폭력대화 확률: 0.6191
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2621
# Class 1 (갈취 대화) 확률: 0.2717
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0129
# Class 3 (기타 괴롭힘 대화) 확률: 0.4533
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 180/500
# 일반대화 확률: 0.5145, 폭력대화 확률: 0.4855
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 181/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 182/500
# 일반대화 확률: 0.1096, 폭력대화 확률: 0.8904
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0327
# Class 1 (갈취 대화) 확률: 0.0283
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0170
# Class 3 (기타 괴롭힘 대화) 확률: 0.9220
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 183/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 184/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 185/500
# 일반대화 확률: 0.0893, 폭력대화 확률: 0.9107
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2208
# Class 1 (갈취 대화) 확률: 0.0369
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0224
# Class 3 (기타 괴롭힘 대화) 확률: 0.7199
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 186/500
# 일반대화 확률: 0.2021, 폭력대화 확률: 0.7979
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0256
# Class 1 (갈취 대화) 확률: 0.0561
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0279
# Class 3 (기타 괴롭힘 대화) 확률: 0.8904
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 187/500
# 일반대화 확률: 0.3951, 폭력대화 확률: 0.6049
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0461
# Class 1 (갈취 대화) 확률: 0.0822
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.5123
# Class 3 (기타 괴롭힘 대화) 확률: 0.3594
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 188/500
# 일반대화 확률: 0.3088, 폭력대화 확률: 0.6912
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9746
# Class 1 (갈취 대화) 확률: 0.0089
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0079
# Class 3 (기타 괴롭힘 대화) 확률: 0.0087
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 189/500
# 일반대화 확률: 0.4467, 폭력대화 확률: 0.5533
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 190/500
# 일반대화 확률: 0.1629, 폭력대화 확률: 0.8371
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2591
# Class 1 (갈취 대화) 확률: 0.0594
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0159
# Class 3 (기타 괴롭힘 대화) 확률: 0.6656
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 191/500
# 일반대화 확률: 0.3635, 폭력대화 확률: 0.6365
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9747
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0093
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 192/500
# 일반대화 확률: 0.0485, 폭력대화 확률: 0.9515
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0267
# Class 1 (갈취 대화) 확률: 0.0245
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0201
# Class 3 (기타 괴롭힘 대화) 확률: 0.9287
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 193/500
# 일반대화 확률: 0.2986, 폭력대화 확률: 0.7014
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0191
# Class 1 (갈취 대화) 확률: 0.9496
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0087
# Class 3 (기타 괴롭힘 대화) 확률: 0.0227
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 194/500
# 일반대화 확률: 0.2063, 폭력대화 확률: 0.7937
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0601
# Class 1 (갈취 대화) 확률: 0.0339
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0346
# Class 3 (기타 괴롭힘 대화) 확률: 0.8714
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 195/500
# 일반대화 확률: 0.1089, 폭력대화 확률: 0.8911
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0188
# Class 1 (갈취 대화) 확률: 0.9483
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0112
# Class 3 (기타 괴롭힘 대화) 확률: 0.0217
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 196/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 197/500
# 일반대화 확률: 0.2126, 폭력대화 확률: 0.7874
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9560
# Class 1 (갈취 대화) 확률: 0.0129
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0071
# Class 3 (기타 괴롭힘 대화) 확률: 0.0241
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 198/500
# 일반대화 확률: 0.2487, 폭력대화 확률: 0.7513
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0510
# Class 1 (갈취 대화) 확률: 0.6084
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.1167
# Class 3 (기타 괴롭힘 대화) 확률: 0.2240
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 199/500
# 일반대화 확률: 0.2141, 폭력대화 확률: 0.7859
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9640
# Class 1 (갈취 대화) 확률: 0.0116
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0066
# Class 3 (기타 괴롭힘 대화) 확률: 0.0178
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 200/500
# 일반대화 확률: 0.0686, 폭력대화 확률: 0.9314
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0278
# Class 1 (갈취 대화) 확률: 0.0273
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0148
# Class 3 (기타 괴롭힘 대화) 확률: 0.9301
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 201/500
# 일반대화 확률: 0.2806, 폭력대화 확률: 0.7194
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0109
# Class 1 (갈취 대화) 확률: 0.0110
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9636
# Class 3 (기타 괴롭힘 대화) 확률: 0.0146
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 202/500
# 일반대화 확률: 0.1203, 폭력대화 확률: 0.8797
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9729
# Class 1 (갈취 대화) 확률: 0.0085
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0106
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 203/500
# 일반대화 확률: 0.3233, 폭력대화 확률: 0.6767
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0499
# Class 1 (갈취 대화) 확률: 0.0276
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0171
# Class 3 (기타 괴롭힘 대화) 확률: 0.9053
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 204/500
# 일반대화 확률: 0.0999, 폭력대화 확률: 0.9001
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0375
# Class 1 (갈취 대화) 확률: 0.8657
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0128
# ...
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 426/500
# 일반대화 확률: 0.3003, 폭력대화 확률: 0.6997
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0214
# Class 1 (갈취 대화) 확률: 0.9500
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0087
# Class 3 (기타 괴롭힘 대화) 확률: 0.0199
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 427/500
# 일반대화 확률: 0.3510, 폭력대화 확률: 0.6490
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.2712
# Class 1 (갈취 대화) 확률: 0.6103
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0118
# Class 3 (기타 괴롭힘 대화) 확률: 0.1066
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 428/500
# 일반대화 확률: 0.3228, 폭력대화 확률: 0.6772
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0101
# Class 1 (갈취 대화) 확률: 0.0108
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9647
# Class 3 (기타 괴롭힘 대화) 확률: 0.0145
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 429/500
# 일반대화 확률: 0.5105, 폭력대화 확률: 0.4895
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 430/500
# 일반대화 확률: 0.4998, 폭력대화 확률: 0.5002
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 431/500
# 일반대화 확률: 0.3231, 폭력대화 확률: 0.6769
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0311
# Class 1 (갈취 대화) 확률: 0.0307
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0154
# Class 3 (기타 괴롭힘 대화) 확률: 0.9227
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 432/500
# 일반대화 확률: 0.2522, 폭력대화 확률: 0.7478
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0580
# Class 1 (갈취 대화) 확률: 0.0365
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0153
# Class 3 (기타 괴롭힘 대화) 확률: 0.8901
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 433/500
# 일반대화 확률: 0.3429, 폭력대화 확률: 0.6571
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.8758
# Class 1 (갈취 대화) 확률: 0.0847
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0103
# Class 3 (기타 괴롭힘 대화) 확률: 0.0291
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 434/500
# 일반대화 확률: 0.5216, 폭력대화 확률: 0.4784
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 435/500
# 일반대화 확률: 0.2812, 폭력대화 확률: 0.7188
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0379
# Class 1 (갈취 대화) 확률: 0.6500
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0149
# Class 3 (기타 괴롭힘 대화) 확률: 0.2972
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 436/500
# 일반대화 확률: 0.1286, 폭력대화 확률: 0.8714
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0299
# Class 1 (갈취 대화) 확률: 0.0263
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0213
# Class 3 (기타 괴롭힘 대화) 확률: 0.9225
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 437/500
# 일반대화 확률: 0.4061, 폭력대화 확률: 0.5939
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 438/500
# 일반대화 확률: 0.2132, 폭력대화 확률: 0.7868
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0373
# Class 1 (갈취 대화) 확률: 0.2478
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0318
# Class 3 (기타 괴롭힘 대화) 확률: 0.6831
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 439/500
# 일반대화 확률: 0.2266, 폭력대화 확률: 0.7734
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0255
# Class 1 (갈취 대화) 확률: 0.0663
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0170
# Class 3 (기타 괴롭힘 대화) 확률: 0.8912
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 440/500
# 일반대화 확률: 0.5145, 폭력대화 확률: 0.4855
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 441/500
# 일반대화 확률: 0.3551, 폭력대화 확률: 0.6449
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0251
# Class 1 (갈취 대화) 확률: 0.0241
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0147
# Class 3 (기타 괴롭힘 대화) 확률: 0.9361
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 442/500
# 일반대화 확률: 0.3728, 폭력대화 확률: 0.6272
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9743
# Class 1 (갈취 대화) 확률: 0.0088
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0092
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 443/500
# 일반대화 확률: 0.3672, 폭력대화 확률: 0.6328
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0097
# Class 1 (갈취 대화) 확률: 0.0100
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9658
# Class 3 (기타 괴롭힘 대화) 확률: 0.0145
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 444/500
# 일반대화 확률: 0.4847, 폭력대화 확률: 0.5153
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 445/500
# 일반대화 확률: 0.2882, 폭력대화 확률: 0.7118
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0359
# Class 1 (갈취 대화) 확률: 0.7976
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0094
# Class 3 (기타 괴롭힘 대화) 확률: 0.1571
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 446/500
# 일반대화 확률: 0.1942, 폭력대화 확률: 0.8058
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0110
# Class 1 (갈취 대화) 확률: 0.0099
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9646
# Class 3 (기타 괴롭힘 대화) 확률: 0.0145
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 447/500
# 일반대화 확률: 0.3531, 폭력대화 확률: 0.6469
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9742
# Class 1 (갈취 대화) 확률: 0.0087
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0094
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 448/500
# 일반대화 확률: 0.2843, 폭력대화 확률: 0.7157
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0119
# Class 1 (갈취 대화) 확률: 0.0107
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9628
# Class 3 (기타 괴롭힘 대화) 확률: 0.0146
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 449/500
# 일반대화 확률: 0.2332, 폭력대화 확률: 0.7668
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0106
# Class 1 (갈취 대화) 확률: 0.0107
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9644
# Class 3 (기타 괴롭힘 대화) 확률: 0.0144
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 450/500
# 일반대화 확률: 0.2040, 폭력대화 확률: 0.7960
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0471
# Class 1 (갈취 대화) 확률: 0.2052
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0254
# Class 3 (기타 괴롭힘 대화) 확률: 0.7222
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 451/500
# 일반대화 확률: 0.1984, 폭력대화 확률: 0.8016
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0275
# Class 1 (갈취 대화) 확률: 0.8883
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0117
# Class 3 (기타 괴롭힘 대화) 확률: 0.0725
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 452/500
# 일반대화 확률: 0.4206, 폭력대화 확률: 0.5794
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 453/500
# 일반대화 확률: 0.4258, 폭력대화 확률: 0.5742
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 454/500
# 일반대화 확률: 0.3599, 폭력대화 확률: 0.6401
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0828
# Class 1 (갈취 대화) 확률: 0.0269
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0197
# Class 3 (기타 괴롭힘 대화) 확률: 0.8706
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 455/500
# 일반대화 확률: 0.3687, 폭력대화 확률: 0.6313
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0103
# Class 1 (갈취 대화) 확률: 0.0106
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9640
# Class 3 (기타 괴롭힘 대화) 확률: 0.0152
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 456/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 457/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 458/500
# 일반대화 확률: 0.3578, 폭력대화 확률: 0.6422
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0535
# Class 1 (갈취 대화) 확률: 0.0789
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.6762
# Class 3 (기타 괴롭힘 대화) 확률: 0.1914
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 459/500
# 일반대화 확률: 0.3494, 폭력대화 확률: 0.6506
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0204
# Class 1 (갈취 대화) 확률: 0.9503
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0216
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 460/500
# 일반대화 확률: 0.3872, 폭력대화 확률: 0.6128
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0361
# Class 1 (갈취 대화) 확률: 0.9186
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0072
# Class 3 (기타 괴롭힘 대화) 확률: 0.0381
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 461/500
# 일반대화 확률: 0.4944, 폭력대화 확률: 0.5056
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 462/500
# 일반대화 확률: 0.5067, 폭력대화 확률: 0.4933
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 463/500
# 일반대화 확률: 0.3874, 폭력대화 확률: 0.6126
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0164
# Class 1 (갈취 대화) 확률: 0.0170
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9482
# Class 3 (기타 괴롭힘 대화) 확률: 0.0184
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 464/500
# 일반대화 확률: 0.4082, 폭력대화 확률: 0.5918
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 465/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 466/500
# 일반대화 확률: 0.2301, 폭력대화 확률: 0.7699
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0231
# Class 1 (갈취 대화) 확률: 0.8673
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0091
# Class 3 (기타 괴롭힘 대화) 확률: 0.1006
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 467/500
# 일반대화 확률: 0.4323, 폭력대화 확률: 0.5677
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 468/500
# 일반대화 확률: 0.2577, 폭력대화 확률: 0.7423
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0110
# Class 1 (갈취 대화) 확률: 0.0118
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9589
# Class 3 (기타 괴롭힘 대화) 확률: 0.0182
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 469/500
# 일반대화 확률: 0.5460, 폭력대화 확률: 0.4540
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 470/500
# 일반대화 확률: 0.3281, 폭력대화 확률: 0.6719
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9750
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0081
# Class 3 (기타 괴롭힘 대화) 확률: 0.0087
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 471/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 472/500
# 일반대화 확률: 0.3292, 폭력대화 확률: 0.6708
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0176
# Class 1 (갈취 대화) 확률: 0.9499
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0083
# Class 3 (기타 괴롭힘 대화) 확률: 0.0243
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 473/500
# 일반대화 확률: 0.3725, 폭력대화 확률: 0.6275
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9741
# Class 1 (갈취 대화) 확률: 0.0082
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0097
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 474/500
# 일반대화 확률: 0.3839, 폭력대화 확률: 0.6161
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0306
# Class 1 (갈취 대화) 확률: 0.0332
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0342
# Class 3 (기타 괴롭힘 대화) 확률: 0.9019
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 475/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 476/500
# 일반대화 확률: 0.3884, 폭력대화 확률: 0.6116
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0101
# Class 1 (갈취 대화) 확률: 0.0105
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9651
# Class 3 (기타 괴롭힘 대화) 확률: 0.0143
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 477/500
# 일반대화 확률: 0.2970, 폭력대화 확률: 0.7030
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0208
# Class 1 (갈취 대화) 확률: 0.9467
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0077
# Class 3 (기타 괴롭힘 대화) 확률: 0.0247
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 478/500
# 일반대화 확률: 0.3491, 폭력대화 확률: 0.6509
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0220
# Class 1 (갈취 대화) 확률: 0.9152
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0080
# Class 3 (기타 괴롭힘 대화) 확률: 0.0548
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 479/500
# 일반대화 확률: 0.1979, 폭력대화 확률: 0.8021
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0496
# Class 1 (갈취 대화) 확률: 0.6979
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0397
# Class 3 (기타 괴롭힘 대화) 확률: 0.2128
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 480/500
# 일반대화 확률: 0.3617, 폭력대화 확률: 0.6383
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0098
# Class 1 (갈취 대화) 확률: 0.0121
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.9624
# Class 3 (기타 괴롭힘 대화) 확률: 0.0157
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 481/500
# 일반대화 확률: 0.5250, 폭력대화 확률: 0.4750
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 482/500
# 일반대화 확률: 0.0802, 폭력대화 확률: 0.9198
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0289
# Class 1 (갈취 대화) 확률: 0.0360
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0152
# Class 3 (기타 괴롭힘 대화) 확률: 0.9198
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 483/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 484/500
# 일반대화 확률: 0.3132, 폭력대화 확률: 0.6868
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9726
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0072
# Class 3 (기타 괴롭힘 대화) 확률: 0.0116
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 485/500
# 일반대화 확률: 0.4448, 폭력대화 확률: 0.5552
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 486/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 487/500
# 일반대화 확률: 0.1488, 폭력대화 확률: 0.8512
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0247
# Class 1 (갈취 대화) 확률: 0.0324
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0216
# Class 3 (기타 괴롭힘 대화) 확률: 0.9214
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 488/500
# 일반대화 확률: 0.2934, 폭력대화 확률: 0.7066
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0481
# Class 1 (갈취 대화) 확률: 0.2695
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0258
# Class 3 (기타 괴롭힘 대화) 확률: 0.6567
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 489/500
# 일반대화 확률: 0.8627, 폭력대화 확률: 0.1373
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 490/500
# 일반대화 확률: 0.3319, 폭력대화 확률: 0.6681
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9617
# Class 1 (갈취 대화) 확률: 0.0130
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0070
# Class 3 (기타 괴롭힘 대화) 확률: 0.0183
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 491/500
# 일반대화 확률: 0.3305, 폭력대화 확률: 0.6695
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0385
# Class 1 (갈취 대화) 확률: 0.0212
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0169
# Class 3 (기타 괴롭힘 대화) 확률: 0.9233
# Multi prediction: 3 (기타 괴롭힘 대화)
# Final prediction: 3 (기타 괴롭힘 대화)
#
# Predicting sample 492/500
# 일반대화 확률: 0.5168, 폭력대화 확률: 0.4832
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 493/500
# 일반대화 확률: 0.2150, 폭력대화 확률: 0.7850
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.9749
# Class 1 (갈취 대화) 확률: 0.0086
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0078
# Class 3 (기타 괴롭힘 대화) 확률: 0.0087
# Multi prediction: 0 (협박 대화)
# Final prediction: 0 (협박 대화)
#
# Predicting sample 494/500
# 일반대화 확률: 0.4455, 폭력대화 확률: 0.5545
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 495/500
# 일반대화 확률: 0.1304, 폭력대화 확률: 0.8696
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0241
# Class 1 (갈취 대화) 확률: 0.9390
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0164
# Class 3 (기타 괴롭힘 대화) 확률: 0.0205
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 496/500
# Rule-based filter triggered: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 497/500
# 일반대화 확률: 0.5052, 폭력대화 확률: 0.4948
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Predicting sample 498/500
# 일반대화 확률: 0.1487, 폭력대화 확률: 0.8513
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0206
# Class 1 (갈취 대화) 확률: 0.9422
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.0127
# Class 3 (기타 괴롭힘 대화) 확률: 0.0244
# Multi prediction: 1 (갈취 대화)
# Final prediction: 1 (갈취 대화)
#
# Predicting sample 499/500
# 일반대화 확률: 0.2401, 폭력대화 확률: 0.7599
# Binary prediction: 1 (폭력대화)
# Class 0 (협박 대화) 확률: 0.0559
# Class 1 (갈취 대화) 확률: 0.0285
# Class 2 (직장 내 괴롭힘 대화) 확률: 0.8447
# Class 3 (기타 괴롭힘 대화) 확률: 0.0709
# Multi prediction: 2 (직장 내 괴롭힘 대화)
# Final prediction: 2 (직장 내 괴롭힘 대화)
#
# Predicting sample 500/500
# 일반대화 확률: 0.5624, 폭력대화 확률: 0.4376
# Binary prediction: 0 (일반대화)
# Final prediction: 4 (일반대화)
#
# Prediction distribution:
# prediction_label
# 기타 괴롭힘 대화      122
# 직장 내 괴롭힘 대화    109
# 일반대화           105
# 갈취 대화           92
# 협박 대화           72
# Name: count, dtype: int64
#
# [INFO] 예측 결과 저장 완료: /content/test_predictions_combined.csv
